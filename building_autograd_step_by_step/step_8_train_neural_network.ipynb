# %%
# In this notebook, you learn:
#
# 1) How to train a simple neural network on a toy dataset?
# 2) How does the performance of the neural network vary based on the complexity of the dataset?

# %%
import math
import random

from graphviz import Digraph
from queue import Queue
from typing import Any, List, Set, Tuple, Union

# %%
def topological_sort(root: Any) -> List[Any]:
    visited: Set[Any] = set()
    topo_order: List[Any] = []
    def dfs(node: Any):
        if node in visited:
            return
        visited.add(node)
        if node.children:
            for child in node.children:
                dfs(child)
        topo_order.append(node)
    dfs(root)
    topo_order.reverse()
    return topo_order

# %%
class Value:
    def __init__(self, data: float, label: str="", operation: str=None, children: Tuple=None):
        self.data = data
        self.label = label
        self.operation = operation
        self.children = children
        self.grad = 0.0
        self.grad_propagator = None
    
    def __add__(self, other: Union['Value', float, int]) -> 'Value':
        if isinstance(other, float) or isinstance(other, int):
            other = Value(other)
        result = Value(self.data + other.data, operation="+", children=(self, other))
        def grad_propagator():
            self.grad += result.grad
            other.grad += result.grad
        result.grad_propagator = grad_propagator
        return result
    
    def __radd__(self, other: Union[float, int]) -> 'Value':
        other: Value = Value(other)
        result = Value(self.data + other.data, operation="+", children=(self, other))
        def grad_propagator():
            self.grad += result.grad
            other.grad += result.grad
        result.grad_propagator = grad_propagator
        return result
    
    def __mul__(self, other: Union['Value', float, int]) -> 'Value':
        if isinstance(other, float) or isinstance(other, int):
            other = Value(other)
        result = Value(self.data * other.data, operation="*", children=(self, other)) 
        def grad_propagator():
            self.grad += result.grad * other.data
            other.grad += result.grad * self.data
        result.grad_propagator = grad_propagator
        return result
    
    def __rmul__(self, other: Union[float, int]) -> 'Value':
        other = Value(other)
        result = Value(self.data * other.data, operation="*", children=(self, other)) 
        def grad_propagator():
            self.grad += result.grad * other.data
            other.grad += result.grad * self.data
        result.grad_propagator = grad_propagator
        return result

    def __sub__(self, other: Union['Value', float, int]) -> 'Value':
        if isinstance(other, float) or isinstance(other, int):
            other = Value(other)
        result = Value(self.data - other.data, operation=f"{self.data}-{other.data}", children=(self, other))
        def grad_propagator():
            self.grad += result.grad
            other.grad -= result.grad
        result.grad_propagator = grad_propagator
        return result

    def __rsub__(self, other: Union[float, int]) -> 'Value':
        other = Value(other)
        result = Value(other.data - self.data, operation=f"{other.data}-{self.data}", children=(other, self))
        def grad_propagator():
            self.grad -= result.grad
            other.grad += result.grad
        result.grad_propagator = grad_propagator
        return result

    def __truediv__(self, other: Union['Value', float, int]) -> 'Value':
        if isinstance(other, float) or isinstance(other, int):
            other = Value(other)
        result = Value(self.data / other.data, operation=f"{self.data}/{other.data}", children=(self, other))
        def grad_propagator():
            self.grad += result.grad / other.data
            other.grad -= ((result.grad * self.data) / other.data**2)
        result.grad_propagator = grad_propagator
        return result

    def __pow__(self, other: Union['Value', float]) -> 'Value':
        if isinstance(other, float) or isinstance(other, int):
            other = Value(other)
        result = Value(self.data ** other.data, operation=f"{self.data}^{other.data}", children=(self, other))
        def grad_propagator():
            self.grad += result.grad * other.data * self.data**(other.data - 1)
            other.grad += result.grad * result.data * math.log(self.data)
        result.grad_propagator = grad_propagator
        return result

    def __rpow__(self, other: Union[int, float]) -> 'Value':
        other = Value(other)
        result = Value(other.data ** self.data, operation=f"{other.data}^{self.data}", children=(other, self))
        def grad_propagator():
            self.grad += result.grad * result.data * math.log(other.data)
            other.grad += result.grad * self.data * other.data**(self.data - 1)
        result.grad_propagator = grad_propagator
        return result

    def tanh(self) -> 'Value':
        computed_data = (math.exp(self.data) - math.exp(-self.data))/(math.exp(self.data) + math.exp(-self.data))
        result = Value(data=computed_data, operation="tanh", children=(self,))
        def grad_propagator():
            # The derivative of tanh is (1 - tanh^2). This is used to calculate the gradients of the children nodes.
            self.grad += (1.0 - computed_data**2) * result.grad
        result.grad_propagator = grad_propagator
        return result

    def backward(self):
        topo_order: List[Value] = topological_sort(self)
        self.grad = 1.0
        for node in topo_order:
            if node.grad_propagator is None:
                continue
            node.grad_propagator()

    def __repr__(self) -> str:
        return f"label: {self.label} | data: {self.data} | operation: {self.operation} | grad: {self.grad}"

# %%
def get_nodes_and_edges(root: Value) -> Tuple[Set[Value], Set[Tuple[Value, Value]]]:
    """Returns all the nodes and edges in the expression tree. Does not nodes for the operations.

    Args:
        root (Value): The root node (the final output object) of the expression tree.

    Returns:
        Tuple[Set[Value], Set[Tuple[Value, Value]]]: A tuple containing the set of nodes and set 
                                                     of edges in the expression tree.
    """
    nodes = set()
    edges = set()
    visited = set()
    queue = Queue()
    queue.put(root)
    while not queue.empty():
        node = queue.get()
        if node in visited:
            continue
        visited.add(node)
        nodes.add(node)
        if node.children:
            for child in node.children:
                edges.add((child, node))
                queue.put(child)
    return nodes, edges

def get_expression_graph(root: Value) -> Digraph:
    """Returns a graph that visualizes the expression created using the Value_4 objects.

    Args:
        root (Value): The root node (the final output object) of the expression tree.

    Returns:
        Digraph: DOT language graph that visualizes the expression created using the Value objects.
    """
    dot = Digraph(name="ExpressionGraph", 
                  comment="Constructs the expression graph using the Value objects.",
                  format="png",
                  graph_attr={"rankdir": "LR"})
    nodes, edges = get_nodes_and_edges(root)
    for node in nodes:
        unique_id: str = str(id(node))
        dot.node(name=unique_id, label=f"{node.label} | data {node.data:.4f} | grad {node.grad:.4f}", shape="record")
        if node.operation:
            dot.node(name=f"{unique_id}_{node.operation}", label=node.operation)
            dot.edge(tail_name=f"{unique_id}_{node.operation}", head_name=unique_id)
    for edge in edges:
        from_node, to_node = edge
        dot.edge(tail_name=str(id(from_node)), head_name=f"{str(id(to_node))}_{to_node.operation}")
    return dot

# %% [markdown]
# ### Trainable Parameters

# %%
# We will use back propagation to calculate the gradients for all the nodes in the expression graph.
# However, during training, we will only update the weights, biases, etc that are created within the neural network.
# The input data should not be updated during training. So, we need to know all the learnable parameters in the 
# expression graph. Lets add 'get_parameters' method to the Perceptron, Layer, and MultiLayerPerceptron classes to 
# get all the learnable parameters in the model.
#
# Note that we don't need to update the 'backward' method in the Value class. The gradients are calculated for the 
# inputs as well but these gradients are not used to update the input data. This will only incur the cost of 
# computation but will not affect the training process.

# %%
class Perceptron:
    def __init__(self, num_inputs: int):
        self.weights = [Value(data=random.uniform(a=0, b=1), label=f"weight") for i in range(num_inputs)]
        self.bias = Value(data=0.0, label="bias")

    def __call__(self, inputs: List[Union[Value, float, int]]) -> Value:
        weighted_sum = self.bias
        for input_value, weight in zip(inputs, self.weights):
            weighted_sum += input_value * weight
        output = weighted_sum.tanh()
        return output

    def get_parameters(self) -> List[Value]:
        return self.weights + [self.bias]

# %%
class Layer:
    def __init__(self, num_inputs: int, num_neurons: int):
        self.neurons = [Perceptron(num_inputs=num_inputs) for _ in range(num_neurons)]
    
    def __call__(self, inputs: List[Union[Value, float, int]]) -> List[Value]:
        outputs = []
        for neuron in self.neurons:
            outputs.append(neuron(inputs))
        return outputs       

    def get_parameters(self) -> List[Value]:
        layer_parameters = []
        for neuron in self.neurons:
            layer_parameters.extend(neuron.get_parameters())
        return layer_parameters

# %%
class MultiLayerPerceptron:
    def __init__(self, num_inputs: int, num_neurons_per_layer: List[int]):
        self.layers = [Layer(num_inputs=num_inputs, num_neurons=num_neurons_per_layer[0])]
        for i in range(1, len(num_neurons_per_layer)):
            self.layers.append(Layer(num_inputs=num_neurons_per_layer[i-1], num_neurons=num_neurons_per_layer[i]))
        
    def __call__(self, inputs: List[Union[Value, float, int]]) -> List[Value]:
        outputs = inputs
        for layer in self.layers:
            outputs = layer(outputs)
        return outputs

    def get_parameters(self) -> List[Value]:
        model_parameters = []
        for layer in self.layers:
            model_parameters.extend(layer.get_parameters())
        return model_parameters

# %%
# Let's create a small dummy neural network and verify that the parameters are being returned correctly.
dummy_model = MultiLayerPerceptron(num_inputs=2, num_neurons_per_layer=[3, 2])
dummy_model.get_parameters()
# Out:
# [label: weight | data: 0.21963017343039903 | operation: None | grad: 0.0,
#  label: weight | data: 0.8568035649102921 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.9597246121444907 | operation: None | grad: 0.0,
#  label: weight | data: 0.5246267035787949 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.9137742356873361 | operation: None | grad: 0.0,
#  label: weight | data: 0.5920915579902988 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.004256141629178423 | operation: None | grad: 0.0,
#  label: weight | data: 0.8448368796571778 | operation: None | grad: 0.0,
#  label: weight | data: 0.6856695584658127 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.28195287285629833 | operation: None | grad: 0.0,
#  label: weight | data: 0.36625420192198876 | operation: None | grad: 0.0,
#  label: weight | data: 0.5578105485666672 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0]

# %% [markdown]
# ## Training a Neural Network

# %%
# We need a dataset to train our neural network. Let's use tiny datasets and train a tiny neural network.
# We don't care if the neural network overfits the data. We just want to make sure that the neural network
# is able to learn the patterns in the data.
#
# About the dataset:
# Lets have 4 data points. Each data point will have 3 features and 1 target.
# 
# About the data generation process, we want to generate a very simple dataset which can be easily 
# learned by a neural network. We can use different kinds of datasets. Lets generate multiple datasets 
# using  different functions and see if the neural network can learn the function that generated the 
# data.

# %%
# We will use a neural network with 2 hidden layers, each having 4 neurons and 1 output layer.
# The neurons will use tanh activation function. We will use mean squared error as the loss function.
# First, let's create the training loop and use it with all the datasets.

# %%
def mean_squared_error(predictions: List[Value], targets: List[int]) -> Value:
    loss = Value(0.0)
    for prediction, target in zip(predictions, targets):
        # Do not use the square operator for the loss calculation. This will causes
        # in the gradient calculation. Full explanation can be found in the next cell.
        # loss += (prediction - target)**2
        loss += (prediction - target) * (prediction - target)
    return loss / len(targets)

# %%
# During the calculation of mean squared error, I noticed that there is an interesting issue we can might
# face using the exponentation (pow) in gradient calculation. There are a few issues with this operation.
# I will highlight two of them:
#
# 1) a^x is not always a real number. For example, (-4)^0.5 is not a complex number. This will result in
#    a complex number in the model calculation which is not desired and can lead to unexpected results.
#    Moreover, it can be extremely difficult to debug such issues.
# 2) The gradient of a^x wrt to x is 'a^x * ln(a)'. Such derivatives will comeup in the gradient calculation
#    when we try to compute the partial derivatives wrt to the learnable parameters. We assume a is 
#    constant and x is the variable. However, as you see, the derivative is 'a^x * ln(a)'. This means it
#    is not defined (atleast not in real numbers) when a is negative. This can lead to issues in the 
#    model training.
#
# Hence, it is good to be cautious when using the power operation in the neural network models.

# %%
def zero_gradients(model: MultiLayerPerceptron):
    for parameter in model.get_parameters():
        parameter.grad = 0.0
    
def update_parameters(model: MultiLayerPerceptron, learning_rate: float):
    for parameter in model.get_parameters():
        parameter.data -= learning_rate * parameter.grad

# %%
def train_model(model: MultiLayerPerceptron, inputs: List[List[float]], targets: List[int], num_epochs: int, learning_rate: float):
    for epoch in range(num_epochs):
        print(f"epoch: {epoch}")
        predictions = []
        for input in inputs:
            predictions.append(model(input)[0])
        print("predictions:")
        for prediction in predictions:
            print(prediction)
        epoch_loss = mean_squared_error(predictions, targets)
        
        # The gradients should always be zeroed out before each backpropagation step.
        # Otherwise, the gradients from previous epoch will accumulate.
        zero_gradients(model=model)
        epoch_loss.backward()
        update_parameters(model=model, learning_rate=learning_rate)
        print(f"epoch_loss: {epoch_loss.data}")
        print("-" * 150)

# %% [markdown]
# ### Even-Odd function

# %%
neural_network1 = MultiLayerPerceptron(num_inputs=3, num_neurons_per_layer=[4, 4, 1])
neural_network1.get_parameters()
# Out:
# [label: weight | data: 0.9166153880414356 | operation: None | grad: 0.0,
#  label: weight | data: 0.44800305292484743 | operation: None | grad: 0.0,
#  label: weight | data: 0.33701992037806805 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.7751071178425 | operation: None | grad: 0.0,
#  label: weight | data: 0.7831780403897577 | operation: None | grad: 0.0,
#  label: weight | data: 0.42712410134571444 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.4614718421959383 | operation: None | grad: 0.0,
#  label: weight | data: 0.49435899515868453 | operation: None | grad: 0.0,
#  label: weight | data: 0.763503834968903 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.1399716942300222 | operation: None | grad: 0.0,
#  label: weight | data: 0.5280850057552526 | operation: None | grad: 0.0,
#  label: weight | data: 0.17019334226852867 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.5978394627537039 | operation: None | grad: 0.0,
#  label: weight | data: 0.24589131305918854 | operation: None | grad: 0.0,
#  label: weight | data: 0.4157815420372586 | operation: None | grad: 0.0,
#  label: weight | data: 0.36680269850580194 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.8245920992149961 | operation: None | grad: 0.0,
#  label: weight | data: 0.10392329800235345 | operation: None | grad: 0.0,
#  label: weight | data: 0.548489772051463 | operation: None | grad: 0.0,
#  label: weight | data: 0.003340753050120271 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.3285719386676764 | operation: None | grad: 0.0,
#  label: weight | data: 0.2925019349536979 | operation: None | grad: 0.0,
#  label: weight | data: 0.3586935047438681 | operation: None | grad: 0.0,
#  label: weight | data: 0.009071649276622296 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.547041287096744 | operation: None | grad: 0.0,
#  label: weight | data: 0.4590405593416912 | operation: None | grad: 0.0,
#  label: weight | data: 0.2929450417826258 | operation: None | grad: 0.0,
#  label: weight | data: 0.6016174196512453 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0,
#  label: weight | data: 0.06892652521727882 | operation: None | grad: 0.0,
#  label: weight | data: 0.6948408323425525 | operation: None | grad: 0.0,
#  label: weight | data: 0.9995034842613462 | operation: None | grad: 0.0,
#  label: weight | data: 0.7893074780440212 | operation: None | grad: 0.0,
#  label: bias | data: 0.0 | operation: None | grad: 0.0]

# %%
# Let's use a function that predicts 1 if the sum of the features is even and -1 if the sum of the features is odd.
# Let's see if the neural network can learn this function.

# %%
# data_point1 = [1, 1, 1]  => sum = 3 (odd)  => target = -1
# data_point2 = [0, 2, 4]  => sum = 6 (even) => target = 1
# data_point3 = [-2, 4, 2] => sum = 4 (even) => target = 1
# data_point4 = [3, 1, 3]  => sum = 7 (odd)  => target = -1
inputs1 = [[1, 1, 1], [0, 2, 4], [-2, 4, 2], [3, 1, 3]]
targets1 = [-1, 1, 1, -1]

# %%
initial_predictions1 = [neural_network1(input)[0] for input in inputs1]
initial_predictions1
# Out:
# [label:  | data: 0.9725899316515488 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9753202140383759 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9663047170258061 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9755487777739069 | operation: tanh | grad: 0.0]

# %%
# Note that the data at the end of 500 epochs are almost the same as the targets. This means that the neural network
# has learned the function that generated the data. This is a very simple function but it is good to see that the
# neural network is able to learn this function.
train_model(model=neural_network1, inputs=inputs1, targets=targets1, num_epochs=500, learning_rate=0.1)
# Out:
# epoch: 0
# predictions:
# label:  | data: 0.9725899316515488 | operation: tanh | grad: 0.0
# label:  | data: 0.9753202140383759 | operation: tanh | grad: 0.0
# label:  | data: 0.9663047170258061 | operation: tanh | grad: 0.0
# label:  | data: 0.9755487777739069 | operation: tanh | grad: 0.0
# epoch_loss: 1.9489121189367156
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 1
# predictions:
# label:  | data: 0.9697381733178587 | operation: tanh | grad: 0.0
# label:  | data: 0.9727190984979154 | operation: tanh | grad: 0.0
# label:  | data: 0.9627824261660209 | operation: tanh | grad: 0.0
# label:  | data: 0.9729767518969389 | operation: tanh | grad: 0.0
# epoch_loss: 1.943658782585056
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 2
# predictions:
# label:  | data: 0.9662498973971859 | operation: tanh | grad: 0.0
# label:  | data: 0.9695304893620408 | operation: tanh | grad: 0.0
# label:  | data: 0.9584752039649742 | operation: tanh | grad: 0.0
# label:  | data: 0.9698246366225708 | operation: tanh | grad: 0.0
# epoch_loss: 1.9372501144559884
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 3
# predictions:
# label:  | data: 0.9618933124832664 | operation: tanh | grad: 0.0
# label:  | data: 0.9655378721578982 | operation: tanh | grad: 0.0
# label:  | data: 0.953098693638858 | operation: tanh | grad: 0.0
# label:  | data: 0.9658788946247487 | operation: tanh | grad: 0.0
# epoch_loss: 1.9292731421728435
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 4
# predictions:
# label:  | data: 0.9563127683528921 | operation: tanh | grad: 0.0
# label:  | data: 0.9604075524785118 | operation: tanh | grad: 0.0
# label:  | data: 0.9462178737102865 | operation: tanh | grad: 0.0
# label:  | data: 0.9608105305556357 | operation: tanh | grad: 0.0
# epoch_loss: 1.9190994158418535
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 5
# predictions:
# label:  | data: 0.9489366418329651 | operation: tanh | grad: 0.0
# label:  | data: 0.953600268843136 | operation: tanh | grad: 0.0
# label:  | data: 0.9371363737810068 | operation: tanh | grad: 0.0
# label:  | data: 0.9540880688219785 | operation: tanh | grad: 0.0
# epoch_loss: 1.9057297462860987
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 6
# predictions:
# label:  | data: 0.9387925914351543 | operation: tanh | grad: 0.0
# label:  | data: 0.9441924658648989 | operation: tanh | grad: 0.0
# label:  | data: 0.924676394790331 | operation: tanh | grad: 0.0
# label:  | data: 0.9448016325203933 | operation: tanh | grad: 0.0
# epoch_loss: 1.8874895572064627
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 7
# predictions:
# label:  | data: 0.9241063116415159 | operation: tanh | grad: 0.0
# label:  | data: 0.9304840448483693 | operation: tanh | grad: 0.0
# label:  | data: 0.9067065459438882 | operation: tanh | grad: 0.0
# label:  | data: 0.9312769227603545 | operation: tanh | grad: 0.0
# epoch_loss: 1.8613879468689463
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 8
# predictions:
# label:  | data: 0.9013426261522425 | operation: tanh | grad: 0.0
# label:  | data: 0.9090479136021428 | operation: tanh | grad: 0.0
# label:  | data: 0.8790339431264171 | operation: tanh | grad: 0.0
# label:  | data: 0.910139849285025 | operation: tanh | grad: 0.0
# epoch_loss: 1.8216607736964474
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 9
# predictions:
# label:  | data: 0.8626446840502332 | operation: tanh | grad: 0.0
# label:  | data: 0.872142716513123 | operation: tanh | grad: 0.0
# label:  | data: 0.8325314938857112 | operation: tanh | grad: 0.0
# label:  | data: 0.8737689942303553 | operation: tanh | grad: 0.0
# epoch_loss: 1.7562121620601066
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 10
# predictions:
# label:  | data: 0.7882171212962159 | operation: tanh | grad: 0.0
# label:  | data: 0.7997979903948149 | operation: tanh | grad: 0.0
# label:  | data: 0.7450377122623071 | operation: tanh | grad: 0.0
# label:  | data: 0.8024871167338958 | operation: tanh | grad: 0.0
# epoch_loss: 1.637941722926748
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 11
# predictions:
# label:  | data: 0.6241793443833379 | operation: tanh | grad: 0.0
# label:  | data: 0.6357418410642336 | operation: tanh | grad: 0.0
# label:  | data: 0.5605511878998872 | operation: tanh | grad: 0.0
# label:  | data: 0.6406431243029788 | operation: tanh | grad: 0.0
# epoch_loss: 1.4138669172129008
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 12
# predictions:
# label:  | data: 0.27675910031474205 | operation: tanh | grad: 0.0
# label:  | data: 0.2773486693049575 | operation: tanh | grad: 0.0
# label:  | data: 0.20010484877019907 | operation: tanh | grad: 0.0
# label:  | data: 0.2851012641281959 | operation: tanh | grad: 0.0
# epoch_loss: 1.1109140645041644
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 13
# predictions:
# label:  | data: -0.011356412605193955 | operation: tanh | grad: 0.0
# label:  | data: -0.021007601335653055 | operation: tanh | grad: 0.0
# label:  | data: -0.07013932003357157 | operation: tanh | grad: 0.0
# label:  | data: -0.01394241428582306 | operation: tanh | grad: 0.0
# epoch_loss: 1.0343450978771105
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 14
# predictions:
# label:  | data: 0.021634082470028827 | operation: tanh | grad: 0.0
# label:  | data: 0.016365778493933187 | operation: tanh | grad: 0.0
# label:  | data: -0.0225278114581805 | operation: tanh | grad: 0.0
# label:  | data: 0.02206366534922874 | operation: tanh | grad: 0.0
# epoch_loss: 1.025362435353695
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 15
# predictions:
# label:  | data: 0.011198737845744315 | operation: tanh | grad: 0.0
# label:  | data: 0.008152204301416412 | operation: tanh | grad: 0.0
# label:  | data: -0.02329911551143599 | operation: tanh | grad: 0.0
# label:  | data: 0.012886567947146795 | operation: tanh | grad: 0.0
# epoch_loss: 1.0198413041468006
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 16
# predictions:
# label:  | data: 0.011211119615989355 | operation: tanh | grad: 0.0
# label:  | data: 0.010621363282701921 | operation: tanh | grad: 0.0
# label:  | data: -0.01598464866943686 | operation: tanh | grad: 0.0
# label:  | data: 0.014606490940796227 | operation: tanh | grad: 0.0
# epoch_loss: 1.0157672882546893
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 17
# predictions:
# label:  | data: 0.008890573841987227 | operation: tanh | grad: 0.0
# label:  | data: 0.0104884176656642 | operation: tanh | grad: 0.0
# label:  | data: -0.01252664605997021 | operation: tanh | grad: 0.0
# label:  | data: 0.013879982462368906 | operation: tanh | grad: 0.0
# epoch_loss: 1.0125390473450904
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 18
# predictions:
# label:  | data: 0.007354959013904127 | operation: tanh | grad: 0.0
# label:  | data: 0.011041351414733266 | operation: tanh | grad: 0.0
# label:  | data: -0.009235490799730689 | operation: tanh | grad: 0.0
# label:  | data: 0.013948275860473704 | operation: tanh | grad: 0.0
# epoch_loss: 1.0098626510179256
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 19
# predictions:
# label:  | data: 0.005753568318712807 | operation: tanh | grad: 0.0
# label:  | data: 0.011420845134371204 | operation: tanh | grad: 0.0
# label:  | data: -0.006679873454388921 | operation: tanh | grad: 0.0
# label:  | data: 0.013924330901964151 | operation: tanh | grad: 0.0
# epoch_loss: 1.0075689755084511
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 20
# predictions:
# label:  | data: 0.004278835545716493 | operation: tanh | grad: 0.0
# label:  | data: 0.01185019368200576 | operation: tanh | grad: 0.0
# label:  | data: -0.004475682752206745 | operation: tanh | grad: 0.0
# label:  | data: 0.01401139964760528 | operation: tanh | grad: 0.0
# epoch_loss: 1.0055516337767894
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 21
# predictions:
# label:  | data: 0.002854232278612137 | operation: tanh | grad: 0.0
# label:  | data: 0.012268432599782 | operation: tanh | grad: 0.0
# label:  | data: -0.0025760283126283097 | operation: tanh | grad: 0.0
# label:  | data: 0.014134094645317744 | operation: tanh | grad: 0.0
# epoch_loss: 1.0037392287268045
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 22
# predictions:
# label:  | data: 0.0014812108170461486 | operation: tanh | grad: 0.0
# label:  | data: 0.012693226199151815 | operation: tanh | grad: 0.0
# label:  | data: -0.0008912146982546655 | operation: tanh | grad: 0.0
# label:  | data: 0.014299091364893364 | operation: tanh | grad: 0.0
# epoch_loss: 1.002081287904103
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 23
# predictions:
# label:  | data: 0.0001431356287851554 | operation: tanh | grad: 0.0
# label:  | data: 0.013121424674821079 | operation: tanh | grad: 0.0
# label:  | data: 0.0006266350583795295 | operation: tanh | grad: 0.0
# label:  | data: 0.014494614887207321 | operation: tanh | grad: 0.0
# epoch_loss: 1.0005405150927784
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 24
# predictions:
# label:  | data: -0.001169268805871742 | operation: tanh | grad: 0.0
# label:  | data: 0.01355616439012778 | operation: tanh | grad: 0.0
# label:  | data: 0.002017767475322378 | operation: tanh | grad: 0.0
# label:  | data: 0.014716770826071613 | operation: tanh | grad: 0.0
# epoch_loss: 0.9990882329552859
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 25
# predictions:
# label:  | data: -0.0024657839099357566 | operation: tanh | grad: 0.0
# label:  | data: 0.013999101318952743 | operation: tanh | grad: 0.0
# label:  | data: 0.003311716752234949 | operation: tanh | grad: 0.0
# label:  | data: 0.014961270199654883 | operation: tanh | grad: 0.0
# epoch_loss: 0.9977015496097315
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 26
# predictions:
# label:  | data: -0.0037549891128820906 | operation: tanh | grad: 0.0
# label:  | data: 0.014452552254069941 | operation: tanh | grad: 0.0
# label:  | data: 0.00453230406937639 | operation: tanh | grad: 0.0
# label:  | data: 0.015225195663601533 | operation: tanh | grad: 0.0
# epoch_loss: 0.9963615062569033
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 27
# predictions:
# label:  | data: -0.005045157526622181 | operation: tanh | grad: 0.0
# label:  | data: 0.014918871650722355 | operation: tanh | grad: 0.0
# label:  | data: 0.005698922096395712 | operation: tanh | grad: 0.0
# label:  | data: 0.015506090246693652 | operation: tanh | grad: 0.0
# epoch_loss: 0.9950518052098763
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 28
# predictions:
# label:  | data: -0.0063443281331594815 | operation: tanh | grad: 0.0
# label:  | data: 0.01540066116904142 | operation: tanh | grad: 0.0
# label:  | data: 0.006828035375872445 | operation: tanh | grad: 0.0
# label:  | data: 0.015801926932664294 | operation: tanh | grad: 0.0
# epoch_loss: 0.9937578895837416
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 29
# predictions:
# label:  | data: -0.0076605786431478765 | operation: tanh | grad: 0.0
# label:  | data: 0.01590076133217611 | operation: tanh | grad: 0.0
# label:  | data: 0.007934085202986151 | operation: tanh | grad: 0.0
# label:  | data: 0.01611088354540407 | operation: tanh | grad: 0.0
# epoch_loss: 0.992466236421725
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 30
# predictions:
# label:  | data: -0.0090022232982036 | operation: tanh | grad: 0.0
# label:  | data: 0.016422329186245227 | operation: tanh | grad: 0.0
# label:  | data: 0.009030236525864708 | operation: tanh | grad: 0.0
# label:  | data: 0.016431205949839812 | operation: tanh | grad: 0.0
# epoch_loss: 0.9911637741249859
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 31
# predictions:
# label:  | data: -0.010378036824032138 | operation: tanh | grad: 0.0
# label:  | data: 0.016968912615509514 | operation: tanh | grad: 0.0
# label:  | data: 0.010128966509260571 | operation: tanh | grad: 0.0
# label:  | data: 0.01676105101404502 | operation: tanh | grad: 0.0
# epoch_loss: 0.98983736164195
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 32
# predictions:
# label:  | data: -0.011797492638173703 | operation: tanh | grad: 0.0
# label:  | data: 0.017544551836208424 | operation: tanh | grad: 0.0
# label:  | data: 0.011242584265071208 | operation: tanh | grad: 0.0
# label:  | data: 0.0170983189324232 | operation: tanh | grad: 0.0
# epoch_loss: 0.9884732801822231
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 33
# predictions:
# label:  | data: -0.013271038619121696 | operation: tanh | grad: 0.0
# label:  | data: 0.018153905595827483 | operation: tanh | grad: 0.0
# label:  | data: 0.012383722515094304 | operation: tanh | grad: 0.0
# label:  | data: 0.01744044674305076 | operation: tanh | grad: 0.0
# epoch_loss: 0.9870566926365887
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 34
# predictions:
# label:  | data: -0.01481042675816147 | operation: tanh | grad: 0.0
# label:  | data: 0.018802413100715953 | operation: tanh | grad: 0.0
# label:  | data: 0.013565847147660655 | operation: tanh | grad: 0.0
# label:  | data: 0.017784139505639573 | operation: tanh | grad: 0.0
# epoch_loss: 0.9855710230760404
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 35
# predictions:
# label:  | data: -0.016429121797814555 | operation: tanh | grad: 0.0
# label:  | data: 0.019496503138429606 | operation: tanh | grad: 0.0
# label:  | data: 0.01480382881322565 | operation: tanh | grad: 0.0
# label:  | data: 0.01812500127906173 | operation: tanh | grad: 0.0
# epoch_loss: 0.9839971984389388
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 36
# predictions:
# label:  | data: -0.01814282189215982 | operation: tanh | grad: 0.0
# label:  | data: 0.02024386821685008 | operation: tanh | grad: 0.0
# label:  | data: 0.01611463010554459 | operation: tanh | grad: 0.0
# label:  | data: 0.018457010316222145 | operation: tanh | grad: 0.0
# epoch_loss: 0.9823126747307946
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 37
# predictions:
# label:  | data: -0.01997013845332047 | operation: tanh | grad: 0.0
# label:  | data: 0.02105382910284604 | operation: tanh | grad: 0.0
# label:  | data: 0.017518178680681326 | operation: tanh | grad: 0.0
# label:  | data: 0.018771751067961782 | operation: tanh | grad: 0.0
# epoch_loss: 0.9804901362586026
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 38
# predictions:
# label:  | data: -0.021933503751695012 | operation: tanh | grad: 0.0
# label:  | data: 0.02193782718774691 | operation: tanh | grad: 0.0
# label:  | data: 0.019038526639859814 | operation: tanh | grad: 0.0
# label:  | data: 0.019057262154911343 | operation: tanh | grad: 0.0
# epoch_loss: 0.9784957001843055
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 39
# predictions:
# label:  | data: -0.024060408773469027 | operation: tanh | grad: 0.0
# label:  | data: 0.022910100558194164 | operation: tanh | grad: 0.0
# label:  | data: 0.02070544670706537 | operation: tanh | grad: 0.0
# label:  | data: 0.019296266576232343 | operation: tanh | grad: 0.0
# epoch_loss: 0.9762863646200151
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 40
# predictions:
# label:  | data: -0.026385128335615758 | operation: tanh | grad: 0.0
# label:  | data: 0.023988628871907006 | operation: tanh | grad: 0.0
# label:  | data: 0.02255670040596698 | operation: tanh | grad: 0.0
# label:  | data: 0.01946338510866992 | operation: tanh | grad: 0.0
# epoch_loss: 0.9738062780989736
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 41
# predictions:
# label:  | data: -0.028951180130714845 | operation: tanh | grad: 0.0
# label:  | data: 0.025196479283203576 | operation: tanh | grad: 0.0
# label:  | data: 0.024641358809173595 | operation: tanh | grad: 0.0
# label:  | data: 0.019520630436173223 | operation: tanh | grad: 0.0
# epoch_loss: 0.9709811273504951
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 42
# predictions:
# label:  | data: -0.03181491571042829 | operation: tanh | grad: 0.0
# label:  | data: 0.02656376345064705 | operation: tanh | grad: 0.0
# label:  | data: 0.02702481303009913 | operation: tanh | grad: 0.0
# label:  | data: 0.019409903421168096 | operation: tanh | grad: 0.0
# epoch_loss: 0.9677094324301105
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 43
# predictions:
# label:  | data: -0.03505090390691312 | operation: tanh | grad: 0.0
# label:  | data: 0.028130546883020625 | operation: tanh | grad: 0.0
# label:  | data: 0.02979658003982397 | operation: tanh | grad: 0.0
# label:  | data: 0.019040076729849763 | operation: tanh | grad: 0.0
# epoch_loss: 0.9638485865091904
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 44
# predictions:
# label:  | data: -0.03876023525796498 | operation: tanh | grad: 0.0
# label:  | data: 0.029951278177220354 | operation: tanh | grad: 0.0
# label:  | data: 0.033082898260936314 | operation: tanh | grad: 0.0
# label:  | data: 0.018263915032683854 | operation: tanh | grad: 0.0
# epoch_loss: 0.9591916225811226
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 45
# predictions:
# label:  | data: -0.04308373205084895 | operation: tanh | grad: 0.0
# label:  | data: 0.03210170400442681 | operation: tanh | grad: 0.0
# label:  | data: 0.037067869427848114 | operation: tanh | grad: 0.0
# label:  | data: 0.016835056835432943 | operation: tanh | grad: 0.0
# epoch_loss: 0.9534269190386518
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 46
# predictions:
# label:  | data: -0.04822364000984893 | operation: tanh | grad: 0.0
# label:  | data: 0.03468994879153476 | operation: tanh | grad: 0.0
# label:  | data: 0.042030569682549514 | operation: tanh | grad: 0.0
# label:  | data: 0.014323956019425224 | operation: tanh | grad: 0.0
# epoch_loss: 0.9460650628944572
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 47
# predictions:
# label:  | data: -0.054480305016942634 | operation: tanh | grad: 0.0
# label:  | data: 0.03787473144071671 | operation: tanh | grad: 0.0
# label:  | data: 0.04841359376946897 | operation: tanh | grad: 0.0
# label:  | data: 0.009944971817357647 | operation: tanh | grad: 0.0
# epoch_loss: 0.9362995151557568
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 48
# predictions:
# label:  | data: -0.06231521386883764 | operation: tanh | grad: 0.0
# label:  | data: 0.041896087521813966 | operation: tanh | grad: 0.0
# label:  | data: 0.05695710244120745 | operation: tanh | grad: 0.0
# label:  | data: 0.00218187228657597 | operation: tanh | grad: 0.0
# epoch_loss: 0.9227285692559404
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 49
# predictions:
# label:  | data: -0.07245618125170152 | operation: tanh | grad: 0.0
# label:  | data: 0.04712893177003965 | operation: tanh | grad: 0.0
# label:  | data: 0.06897747449862128 | operation: tanh | grad: 0.0
# label:  | data: -0.012055019739391343 | operation: tanh | grad: 0.0
# epoch_loss: 0.9027847588452454
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 50
# predictions:
# label:  | data: -0.08603737242341304 | operation: tanh | grad: 0.0
# label:  | data: 0.05418603696938172 | operation: tanh | grad: 0.0
# label:  | data: 0.08697884642785557 | operation: tanh | grad: 0.0
# label:  | data: -0.03928656648940753 | operation: tanh | grad: 0.0
# epoch_loss: 0.8716174163670759
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 51
# predictions:
# label:  | data: -0.10453622191693199 | operation: tanh | grad: 0.0
# label:  | data: 0.06420169879663705 | operation: tanh | grad: 0.0
# label:  | data: 0.11600176913089416 | operation: tanh | grad: 0.0
# label:  | data: -0.09252028227981238 | operation: tanh | grad: 0.0
# epoch_loss: 0.8206365371617806
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 52
# predictions:
# label:  | data: -0.1280087603134829 | operation: tanh | grad: 0.0
# label:  | data: 0.08021999542367506 | operation: tanh | grad: 0.0
# label:  | data: 0.1659287195241302 | operation: tanh | grad: 0.0
# label:  | data: -0.18804980497052673 | operation: tanh | grad: 0.0
# epoch_loss: 0.7403254997578774
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 53
# predictions:
# label:  | data: -0.14856042094301447 | operation: tanh | grad: 0.0
# label:  | data: 0.11294554581839839 | operation: tanh | grad: 0.0
# label:  | data: 0.24905712229211974 | operation: tanh | grad: 0.0
# label:  | data: -0.3091751267938267 | operation: tanh | grad: 0.0
# epoch_loss: 0.6382422931221685
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 54
# predictions:
# label:  | data: -0.16050642049622035 | operation: tanh | grad: 0.0
# label:  | data: 0.172642739075545 | operation: tanh | grad: 0.0
# label:  | data: 0.3509871746361914 | operation: tanh | grad: 0.0
# label:  | data: -0.40519108879318017 | operation: tanh | grad: 0.0
# epoch_loss: 0.5410711988925604
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 55
# predictions:
# label:  | data: -0.19195773661879553 | operation: tanh | grad: 0.0
# label:  | data: 0.230862068511313 | operation: tanh | grad: 0.0
# label:  | data: 0.43009243664603497 | operation: tanh | grad: 0.0
# label:  | data: -0.48893997691264257 | operation: tanh | grad: 0.0
# epoch_loss: 0.45762060875775495
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 56
# predictions:
# label:  | data: -0.23228940683059862 | operation: tanh | grad: 0.0
# label:  | data: 0.2935775765275582 | operation: tanh | grad: 0.0
# label:  | data: 0.4940104161899843 | operation: tanh | grad: 0.0
# label:  | data: -0.5585631904345751 | operation: tanh | grad: 0.0
# epoch_loss: 0.38482602775318153
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 57
# predictions:
# label:  | data: -0.2860128101973416 | operation: tanh | grad: 0.0
# label:  | data: 0.34742873023258936 | operation: tanh | grad: 0.0
# label:  | data: 0.543365684906808 | operation: tanh | grad: 0.0
# label:  | data: -0.6223747142661153 | operation: tanh | grad: 0.0
# epoch_loss: 0.3216856808685936
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 58
# predictions:
# label:  | data: -0.3374934862552283 | operation: tanh | grad: 0.0
# label:  | data: 0.4027956346625604 | operation: tanh | grad: 0.0
# label:  | data: 0.5878450565823398 | operation: tanh | grad: 0.0
# label:  | data: -0.6732390203244533 | operation: tanh | grad: 0.0
# epoch_loss: 0.2680530924886208
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 59
# predictions:
# label:  | data: -0.39279613697768806 | operation: tanh | grad: 0.0
# label:  | data: 0.4486012063621401 | operation: tanh | grad: 0.0
# label:  | data: 0.6243297112380221 | operation: tanh | grad: 0.0
# label:  | data: -0.717102216569361 | operation: tanh | grad: 0.0
# epoch_loss: 0.22347412065574562
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 60
# predictions:
# label:  | data: -0.4408789151788447 | operation: tanh | grad: 0.0
# label:  | data: 0.49367288475844456 | operation: tanh | grad: 0.0
# label:  | data: 0.6576156457681356 | operation: tanh | grad: 0.0
# label:  | data: -0.7509868853039414 | operation: tanh | grad: 0.0
# epoch_loss: 0.18705452810845602
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 61
# predictions:
# label:  | data: -0.48695237877150943 | operation: tanh | grad: 0.0
# label:  | data: 0.5313209452221825 | operation: tanh | grad: 0.0
# label:  | data: 0.6854332555450444 | operation: tanh | grad: 0.0
# label:  | data: -0.7791950568499849 | operation: tanh | grad: 0.0
# epoch_loss: 0.15764624441802796
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 62
# predictions:
# label:  | data: -0.5264126297879944 | operation: tanh | grad: 0.0
# label:  | data: 0.5660509488289601 | operation: tanh | grad: 0.0
# label:  | data: 0.7100171051675465 | operation: tanh | grad: 0.0
# label:  | data: -0.8014486761165835 | operation: tanh | grad: 0.0
# epoch_loss: 0.13402737093695904
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 63
# predictions:
# label:  | data: -0.5617030579238674 | operation: tanh | grad: 0.0
# label:  | data: 0.595927524211781 | operation: tanh | grad: 0.0
# label:  | data: 0.7309723728840892 | operation: tanh | grad: 0.0
# label:  | data: -0.8197585869817093 | operation: tanh | grad: 0.0
# epoch_loss: 0.11506040156033928
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 64
# predictions:
# label:  | data: -0.5922808834811237 | operation: tanh | grad: 0.0
# label:  | data: 0.6223768867804818 | operation: tanh | grad: 0.0
# label:  | data: 0.7491615112761377 | operation: tanh | grad: 0.0
# label:  | data: -0.8347226627570433 | operation: tanh | grad: 0.0
# epoch_loss: 0.09976765981098183
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 65
# predictions:
# label:  | data: -0.6190200921748772 | operation: tanh | grad: 0.0
# label:  | data: 0.6455392690953006 | operation: tanh | grad: 0.0
# label:  | data: 0.764908897730267 | operation: tanh | grad: 0.0
# label:  | data: -0.8471686781761458 | operation: tanh | grad: 0.0
# epoch_loss: 0.08735333480418933
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 66
# predictions:
# label:  | data: -0.6423890398982863 | operation: tanh | grad: 0.0
# label:  | data: 0.665933958392006 | operation: tanh | grad: 0.0
# label:  | data: 0.7786313371146724 | operation: tanh | grad: 0.0
# label:  | data: -0.8576215061216564 | operation: tanh | grad: 0.0
# epoch_loss: 0.0771903598418017
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 67
# predictions:
# label:  | data: -0.6628985360576882 | operation: tanh | grad: 0.0
# label:  | data: 0.683948800296237 | operation: tanh | grad: 0.0
# label:  | data: 0.7906539894641318 | operation: tanh | grad: 0.0
# label:  | data: -0.8665008455355777 | operation: tanh | grad: 0.0
# epoch_loss: 0.06879338354905928
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 68
# predictions:
# label:  | data: -0.6809824077119236 | operation: tanh | grad: 0.0
# label:  | data: 0.6999322941782355 | operation: tanh | grad: 0.0
# label:  | data: 0.8012510242299158 | operation: tanh | grad: 0.0
# label:  | data: -0.8741228590639323 | operation: tanh | grad: 0.0
# epoch_loss: 0.06178976556157863
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 69
# predictions:
# label:  | data: -0.6970095940015986 | operation: tanh | grad: 0.0
# label:  | data: 0.714181038993896 | operation: tanh | grad: 0.0
# label:  | data: 0.8106480333392769 | operation: tanh | grad: 0.0
# label:  | data: -0.8807296116257101 | operation: tanh | grad: 0.0
# epoch_loss: 0.05589381435473062
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 70
# predictions:
# label:  | data: -0.7112890164772891 | operation: tanh | grad: 0.0
# label:  | data: 0.726945155612798 | operation: tanh | grad: 0.0
# label:  | data: 0.8190301083786975 | operation: tanh | grad: 0.0
# label:  | data: -0.8865078589380557 | operation: tanh | grad: 0.0
# epoch_loss: 0.05088588695155508
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 71
# predictions:
# label:  | data: -0.7240777141366883 | operation: tanh | grad: 0.0
# label:  | data: 0.7384343857460421 | operation: tanh | grad: 0.0
# label:  | data: 0.8265490936716122 | operation: tanh | grad: 0.0
# label:  | data: -0.891603056454333 | operation: tanh | grad: 0.0
# epoch_loss: 0.04659619816806676
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 72
# predictions:
# label:  | data: -0.7355891659778151 | operation: tanh | grad: 0.0
# label:  | data: 0.7488242959523486 | operation: tanh | grad: 0.0
# label:  | data: 0.8333298491223725 | operation: tanh | grad: 0.0
# label:  | data: -0.8961296197167624 | operation: tanh | grad: 0.0
# epoch_loss: 0.042892579636474075
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 73
# predictions:
# label:  | data: -0.7460008451571112 | operation: tanh | grad: 0.0
# label:  | data: 0.7582619510724787 | operation: tanh | grad: 0.0
# label:  | data: 0.8394754437282197 | operation: tanh | grad: 0.0
# label:  | data: -0.9001784458571018 | operation: tanh | grad: 0.0
# epoch_loss: 0.0396713326994855
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 74
# predictions:
# label:  | data: -0.7554606932479683 | operation: tanh | grad: 0.0
# label:  | data: 0.7668708290456252 | operation: tanh | grad: 0.0
# label:  | data: 0.8450713676162256 | operation: tanh | grad: 0.0
# label:  | data: -0.9038224522243442 | operation: tanh | grad: 0.0
# epoch_loss: 0.036850421181270916
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 75
# predictions:
# label:  | data: -0.7640925024332974 | operation: tanh | grad: 0.0
# label:  | data: 0.7747549528631862 | operation: tanh | grad: 0.0
# label:  | data: 0.8501889079377682 | operation: tanh | grad: 0.0
# label:  | data: -0.9071206821209191 | operation: tanh | grad: 0.0
# epoch_loss: 0.03436440241560278
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 76
# predictions:
# label:  | data: -0.7720003164198488 | operation: tanh | grad: 0.0
# label:  | data: 0.7820023060460756 | operation: tanh | grad: 0.0
# label:  | data: 0.8548878397802366 | operation: tanh | grad: 0.0
# label:  | data: -0.9101213724711639 | operation: tanh | grad: 0.0
# epoch_loss: 0.03216063925299788
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 77
# predictions:
# label:  | data: -0.7792719982546602 | operation: tanh | grad: 0.0
# label:  | data: 0.7886876298945574 | operation: tanh | grad: 0.0
# label:  | data: 0.8592185678400411 | operation: tanh | grad: 0.0
# label:  | data: -0.9128642655464343 | operation: tanh | grad: 0.0
# epoch_loss: 0.03019645409346042
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 78
# predictions:
# label:  | data: -0.7859821119852295 | operation: tanh | grad: 0.0
# label:  | data: 0.7948747042049674 | operation: tanh | grad: 0.0
# label:  | data: 0.8632238327365859 | operation: tanh | grad: 0.0
# label:  | data: -0.9153823664479398 | operation: tanh | grad: 0.0
# epoch_loss: 0.02843697680113066
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 79
# predictions:
# label:  | data: -0.7921942485640451 | operation: tanh | grad: 0.0
# label:  | data: 0.8006182042556732 | operation: tanh | grad: 0.0
# label:  | data: 0.8669400741265182 | operation: tanh | grad: 0.0
# label:  | data: -0.9177032910857976 | operation: tanh | grad: 0.0
# epoch_loss: 0.026853505743914943
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 80
# predictions:
# label:  | data: -0.7979629056226669 | operation: tanh | grad: 0.0
# label:  | data: 0.8059652137454174 | operation: tanh | grad: 0.0
# label:  | data: 0.87039852373223 | operation: tanh | grad: 0.0
# label:  | data: -0.9198503091063509 | operation: tanh | grad: 0.0
# epoch_loss: 0.025422250345607446
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 81
# predictions:
# label:  | data: -0.8033350106113737 | operation: tanh | grad: 0.0
# label:  | data: 0.8109564598617347 | operation: tanh | grad: 0.0
# label:  | data: 0.8736260856677976 | operation: tanh | grad: 0.0
# label:  | data: -0.921843157664054 | operation: tanh | grad: 0.0
# epoch_loss: 0.024123359086701292
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 82
# predictions:
# label:  | data: -0.8083511591761614 | operation: tanh | grad: 0.0
# label:  | data: 0.8156273244010132 | operation: tanh | grad: 0.0
# label:  | data: 0.8766460488637247 | operation: tanh | grad: 0.0
# label:  | data: -0.9236986816016666 | operation: tanh | grad: 0.0
# epoch_loss: 0.022940162536726177
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 83
# predictions:
# label:  | data: -0.8130466259740001 | operation: tanh | grad: 0.0
# label:  | data: 0.8200086743975591 | operation: tanh | grad: 0.0
# label:  | data: 0.8794786665079617 | operation: tanh | grad: 0.0
# label:  | data: -0.9254313410385551 | operation: tanh | grad: 0.0
# epoch_loss: 0.021858579519459173
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 84
# predictions:
# label:  | data: -0.8174521932499844 | operation: tanh | grad: 0.0
# label:  | data: 0.8241275470791551 | operation: tanh | grad: 0.0
# label:  | data: 0.8821416297323047 | operation: tanh | grad: 0.0
# label:  | data: -0.9270536168634599 | operation: tanh | grad: 0.0
# epoch_loss: 0.020866647925123973
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 85
# predictions:
# label:  | data: -0.8215948330356247 | operation: tanh | grad: 0.0
# label:  | data: 0.8280077169702 | operation: tanh | grad: 0.0
# label:  | data: 0.88465045682171 | operation: tanh | grad: 0.0
# label:  | data: -0.9285763369973344 | operation: tanh | grad: 0.0
# epoch_loss: 0.01995415144238699
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 86
# predictions:
# label:  | data: -0.8254982713524153 | operation: tanh | grad: 0.0
# label:  | data: 0.8316701673617497 | operation: tanh | grad: 0.0
# label:  | data: 0.8870188146245619 | operation: tanh | grad: 0.0
# label:  | data: -0.9300089407059178 | operation: tanh | grad: 0.0
# epoch_loss: 0.019112320621740873
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 87
# predictions:
# label:  | data: -0.82918345692752 | operation: tanh | grad: 0.0
# label:  | data: 0.8351334839108912 | operation: tanh | grad: 0.0
# label:  | data: 0.8892587852857257 | operation: tanh | grad: 0.0
# label:  | data: -0.931359694121205 | operation: tanh | grad: 0.0
# epoch_loss: 0.018333591935530084
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 88
# predictions:
# label:  | data: -0.8326689523152648 | operation: tanh | grad: 0.0
# label:  | data: 0.8384141845968431 | operation: tanh | grad: 0.0
# label:  | data: 0.8913810886694252 | operation: tanh | grad: 0.0
# label:  | data: -0.932635867068176 | operation: tanh | grad: 0.0
# epoch_loss: 0.01761141239076748
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 89
# predictions:
# label:  | data: -0.8359712616965445 | operation: tanh | grad: 0.0
# label:  | data: 0.841526997459851 | operation: tanh | grad: 0.0
# label:  | data: 0.8933952686989746 | operation: tanh | grad: 0.0
# label:  | data: -0.9338438789993868 | operation: tanh | grad: 0.0
# epoch_loss: 0.016940080151281293
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 90
# predictions:
# label:  | data: -0.8391051067809483 | operation: tanh | grad: 0.0
# label:  | data: 0.8444850953278161 | operation: tanh | grad: 0.0
# label:  | data: 0.8953098501721224 | operation: tanh | grad: 0.0
# label:  | data: -0.9349894201095381 | operation: tanh | grad: 0.0
# epoch_loss: 0.01631461380196152
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 91
# predictions:
# label:  | data: -0.8420836599926127 | operation: tanh | grad: 0.0
# label:  | data: 0.8473002949716549 | operation: tanh | grad: 0.0
# label:  | data: 0.897132471305147 | operation: tanh | grad: 0.0
# label:  | data: -0.9360775523872085 | operation: tanh | grad: 0.0
# epoch_loss: 0.01573064453141721
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 92
# predictions:
# label:  | data: -0.8449187423473489 | operation: tanh | grad: 0.0
# label:  | data: 0.8499832267263198 | operation: tanh | grad: 0.0
# label:  | data: 0.8988699962327484 | operation: tanh | grad: 0.0
# label:  | data: -0.9371127943548606 | operation: tanh | grad: 0.0
# epoch_loss: 0.01518432675859828
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 93
# predictions:
# label:  | data: -0.8476209920222244 | operation: tanh | grad: 0.0
# label:  | data: 0.8525434794936001 | operation: tanh | grad: 0.0
# label:  | data: 0.9005286108808498 | operation: tanh | grad: 0.0
# label:  | data: -0.9380991924732429 | operation: tanh | grad: 0.0
# epoch_loss: 0.014672263684475838
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 94
# predictions:
# label:  | data: -0.8502000084994046 | operation: tanh | grad: 0.0
# label:  | data: 0.8549897251453635 | operation: tanh | grad: 0.0
# label:  | data: 0.9021139049872647 | operation: tanh | grad: 0.0
# label:  | data: -0.9390403815854881 | operation: tanh | grad: 0.0
# epoch_loss: 0.014191444985270201
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 95
# predictions:
# label:  | data: -0.8526644762717859 | operation: tanh | grad: 0.0
# label:  | data: 0.8573298256247738 | operation: tanh | grad: 0.0
# label:  | data: 0.9036309425337782 | operation: tanh | grad: 0.0
# label:  | data: -0.9399396363074793 | operation: tanh | grad: 0.0
# epoch_loss: 0.013739194433082606
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 96
# predictions:
# label:  | data: -0.8550222713806882 | operation: tanh | grad: 0.0
# label:  | data: 0.8595709254616122 | operation: tanh | grad: 0.0
# label:  | data: 0.9050843224440861 | operation: tanh | grad: 0.0
# label:  | data: -0.9407999149031915 | operation: tanh | grad: 0.0
# epoch_loss: 0.013313125673172622
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 97
# predictions:
# label:  | data: -0.8572805534783264 | operation: tanh | grad: 0.0
# label:  | data: 0.8617195319473101 | operation: tanh | grad: 0.0
# label:  | data: 0.9064782310733409 | operation: tanh | grad: 0.0
# label:  | data: -0.9416238968933281 | operation: tanh | grad: 0.0
# epoch_loss: 0.01291110473435401
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 98
# predictions:
# label:  | data: -0.8594458456409025 | operation: tanh | grad: 0.0
# label:  | data: 0.8637815848331609 | operation: tanh | grad: 0.0
# label:  | data: 0.9078164877497887 | operation: tanh | grad: 0.0
# label:  | data: -0.9424140154150701 | operation: tanh | grad: 0.0
# epoch_loss: 0.012531218122391743
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 99
# predictions:
# label:  | data: -0.8615241037792611 | operation: tanh | grad: 0.0
# label:  | data: 0.8657625171036853 | operation: tanh | grad: 0.0
# label:  | data: 0.9091025844140399 | operation: tanh | grad: 0.0
# label:  | data: -0.9431724851668153 | operation: tanh | grad: 0.0
# epoch_loss: 0.012171745562699444
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 100
# predictions:
# label:  | data: -0.8635207771853532 | operation: tanh | grad: 0.0
# label:  | data: 0.8676673081222688 | operation: tanh | grad: 0.0
# label:  | data: 0.9103397202265704 | operation: tanh | grad: 0.0
# label:  | data: -0.9439013266242406 | operation: tanh | grad: 0.0
# epoch_loss: 0.011831136630816587
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 101
# predictions:
# label:  | data: -0.8654408615003004 | operation: tanh | grad: 0.0
# label:  | data: 0.8695005302369461 | operation: tanh | grad: 0.0
# label:  | data: 0.9115308318711292 | operation: tanh | grad: 0.0
# label:  | data: -0.9446023870950762 | operation: tanh | grad: 0.0
# epoch_loss: 0.01150799064679944
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 102
# predictions:
# label:  | data: -0.8672889451826156 | operation: tanh | grad: 0.0
# ...
# epoch: 466
# predictions:
# label:  | data: -0.9626638218495004 | operation: tanh | grad: 0.0
# label:  | data: 0.9639135395696332 | operation: tanh | grad: 0.0
# label:  | data: 0.9741408890219115 | operation: tanh | grad: 0.0
# label:  | data: -0.9817366700294722 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009246164168669368
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 467
# predictions:
# label:  | data: -0.9627134152881047 | operation: tanh | grad: 0.0
# label:  | data: 0.9639621103229091 | operation: tanh | grad: 0.0
# label:  | data: 0.9741742428542239 | operation: tanh | grad: 0.0
# label:  | data: -0.9817576397869626 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009221930825375819
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 468
# predictions:
# label:  | data: -0.9627628182620588 | operation: tanh | grad: 0.0
# label:  | data: 0.9640104941376462 | operation: tanh | grad: 0.0
# label:  | data: 0.9742074703762735 | operation: tanh | grad: 0.0
# label:  | data: -0.9817785333386702 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009197821669204065
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 469
# predictions:
# label:  | data: -0.9628120319740846 | operation: tanh | grad: 0.0
# label:  | data: 0.9640586921938024 | operation: tanh | grad: 0.0
# label:  | data: 0.97424057237732 | operation: tanh | grad: 0.0
# label:  | data: -0.9817993511504113 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009173835756776187
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 470
# predictions:
# label:  | data: -0.9628610576163619 | operation: tanh | grad: 0.0
# label:  | data: 0.9641067056610074 | operation: tanh | grad: 0.0
# label:  | data: 0.9742735496397659 | operation: tanh | grad: 0.0
# label:  | data: -0.9818200936840096 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009149972154191322
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 471
# predictions:
# label:  | data: -0.9629098963706455 | operation: tanh | grad: 0.0
# label:  | data: 0.964154535698679 | operation: tanh | grad: 0.0
# label:  | data: 0.9743064029392313 | operation: tanh | grad: 0.0
# label:  | data: -0.9818407613973392 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009126229936907593
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 472
# predictions:
# label:  | data: -0.9629585494083837 | operation: tanh | grad: 0.0
# label:  | data: 0.9642021834561358 | operation: tanh | grad: 0.0
# label:  | data: 0.9743391330446306 | operation: tanh | grad: 0.0
# label:  | data: -0.981861354744367 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009102608189625442
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 473
# predictions:
# label:  | data: -0.9630070178908321 | operation: tanh | grad: 0.0
# label:  | data: 0.964249650072711 | operation: tanh | grad: 0.0
# label:  | data: 0.9743717407182462 | operation: tanh | grad: 0.0
# label:  | data: -0.9818818741751973 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009079106006172525
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 474
# predictions:
# label:  | data: -0.963055302969166 | operation: tanh | grad: 0.0
# label:  | data: 0.9642969366778612 | operation: tanh | grad: 0.0
# label:  | data: 0.9744042267158006 | operation: tanh | grad: 0.0
# label:  | data: -0.9819023201361126 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009055722489391651
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 475
# predictions:
# label:  | data: -0.9631034057845934 | operation: tanh | grad: 0.0
# label:  | data: 0.9643440443912777 | operation: tanh | grad: 0.0
# label:  | data: 0.9744365917865301 | operation: tanh | grad: 0.0
# label:  | data: -0.981922693069616 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009032456751028395
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 476
# predictions:
# label:  | data: -0.9631513274684652 | operation: tanh | grad: 0.0
# label:  | data: 0.9643909743229935 | operation: tanh | grad: 0.0
# label:  | data: 0.9744688366732555 | operation: tanh | grad: 0.0
# label:  | data: -0.9819429934144724 | operation: tanh | grad: 0.0
# epoch_loss: 0.0009009307911621719
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 477
# predictions:
# label:  | data: -0.9631990691423832 | operation: tanh | grad: 0.0
# label:  | data: 0.964437727573489 | operation: tanh | grad: 0.0
# label:  | data: 0.9745009621124517 | operation: tanh | grad: 0.0
# label:  | data: -0.9819632216057489 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008986275100396059
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 478
# predictions:
# label:  | data: -0.963246631918308 | operation: tanh | grad: 0.0
# label:  | data: 0.9644843052337976 | operation: tanh | grad: 0.0
# label:  | data: 0.9745329688343181 | operation: tanh | grad: 0.0
# label:  | data: -0.9819833780748541 | operation: tanh | grad: 0.0
# epoch_loss: 0.000896335745515465
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 479
# predictions:
# label:  | data: -0.9632940168986646 | operation: tanh | grad: 0.0
# label:  | data: 0.9645307083856102 | operation: tanh | grad: 0.0
# label:  | data: 0.9745648575628456 | operation: tanh | grad: 0.0
# label:  | data: -0.9820034632495792 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008940554122174315
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 480
# predictions:
# label:  | data: -0.9633412251764472 | operation: tanh | grad: 0.0
# label:  | data: 0.9645769381013753 | operation: tanh | grad: 0.0
# label:  | data: 0.974596629015886 | operation: tanh | grad: 0.0
# label:  | data: -0.9820234775541361 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008917864256102303
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 481
# predictions:
# label:  | data: -0.9633882578353217 | operation: tanh | grad: 0.0
# label:  | data: 0.9646229954444017 | operation: tanh | grad: 0.0
# label:  | data: 0.9746282839052163 | operation: tanh | grad: 0.0
# label:  | data: -0.9820434214091951 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008895287019854428
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 482
# predictions:
# label:  | data: -0.9634351159497283 | operation: tanh | grad: 0.0
# label:  | data: 0.9646688814689568 | operation: tanh | grad: 0.0
# label:  | data: 0.9746598229366066 | operation: tanh | grad: 0.0
# label:  | data: -0.9820632952319249 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008872821584514138
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 483
# predictions:
# label:  | data: -0.9634818005849806 | operation: tanh | grad: 0.0
# label:  | data: 0.9647145972203649 | operation: tanh | grad: 0.0
# label:  | data: 0.9746912468098843 | operation: tanh | grad: 0.0
# label:  | data: -0.9820830994360279 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008850467129234157
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 484
# predictions:
# label:  | data: -0.963528312797366 | operation: tanh | grad: 0.0
# label:  | data: 0.964760143735105 | operation: tanh | grad: 0.0
# label:  | data: 0.9747225562189961 | operation: tanh | grad: 0.0
# label:  | data: -0.9821028344317788 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008828222841138442
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 485
# predictions:
# label:  | data: -0.9635746536342424 | operation: tanh | grad: 0.0
# label:  | data: 0.9648055220409056 | operation: tanh | grad: 0.0
# label:  | data: 0.974753751852075 | operation: tanh | grad: 0.0
# label:  | data: -0.9821225006260601 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008806087915226032
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 486
# predictions:
# label:  | data: -0.963620824134135 | operation: tanh | grad: 0.0
# label:  | data: 0.9648507331568386 | operation: tanh | grad: 0.0
# label:  | data: 0.9747848343914992 | operation: tanh | grad: 0.0
# label:  | data: -0.982142098422399 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008784061554276779
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 487
# predictions:
# label:  | data: -0.9636668253268316 | operation: tanh | grad: 0.0
# label:  | data: 0.9648957780934132 | operation: tanh | grad: 0.0
# label:  | data: 0.9748158045139554 | operation: tanh | grad: 0.0
# label:  | data: -0.982161628221002 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008762142968757296
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 488
# predictions:
# label:  | data: -0.9637126582334763 | operation: tanh | grad: 0.0
# label:  | data: 0.9649406578526682 | operation: tanh | grad: 0.0
# label:  | data: 0.9748466628904989 | operation: tanh | grad: 0.0
# label:  | data: -0.9821810904187914 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008740331376729147
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 489
# predictions:
# label:  | data: -0.9637583238666624 | operation: tanh | grad: 0.0
# label:  | data: 0.9649853734282611 | operation: tanh | grad: 0.0
# label:  | data: 0.974877410186614 | operation: tanh | grad: 0.0
# label:  | data: -0.9822004854094378 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008718626003758353
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 490
# predictions:
# label:  | data: -0.9638038232305234 | operation: tanh | grad: 0.0
# label:  | data: 0.9650299258055586 | operation: tanh | grad: 0.0
# label:  | data: 0.9749080470622722 | operation: tanh | grad: 0.0
# label:  | data: -0.9822198135833972 | operation: tanh | grad: 0.0
# epoch_loss: 0.000869702608282558
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 491
# predictions:
# label:  | data: -0.9638491573208239 | operation: tanh | grad: 0.0
# label:  | data: 0.9650743159617257 | operation: tanh | grad: 0.0
# label:  | data: 0.9749385741719924 | operation: tanh | grad: 0.0
# label:  | data: -0.9822390753279413 | operation: tanh | grad: 0.0
# epoch_loss: 0.000867553085423796
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 492
# predictions:
# label:  | data: -0.9638943271250487 | operation: tanh | grad: 0.0
# label:  | data: 0.9651185448658114 | operation: tanh | grad: 0.0
# label:  | data: 0.9749689921648959 | operation: tanh | grad: 0.0
# label:  | data: -0.9822582710271944 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008654139565542344
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 493
# predictions:
# label:  | data: -0.9639393336224902 | operation: tanh | grad: 0.0
# label:  | data: 0.9651626134788354 | operation: tanh | grad: 0.0
# label:  | data: 0.9749993016847668 | operation: tanh | grad: 0.0
# label:  | data: -0.9822774010621639 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008632851471439465
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 494
# predictions:
# label:  | data: -0.9639841777843356 | operation: tanh | grad: 0.0
# label:  | data: 0.9652065227538732 | operation: tanh | grad: 0.0
# label:  | data: 0.975029503370104 | operation: tanh | grad: 0.0
# label:  | data: -0.9822964658107736 | operation: tanh | grad: 0.0
# epoch_loss: 0.000861166583369961
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 495
# predictions:
# label:  | data: -0.9640288605737527 | operation: tanh | grad: 0.0
# label:  | data: 0.9652502736361402 | operation: tanh | grad: 0.0
# label:  | data: 0.975059597854181 | operation: tanh | grad: 0.0
# label:  | data: -0.9823154656478953 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008590581921079
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 496
# predictions:
# label:  | data: -0.9640733829459747 | operation: tanh | grad: 0.0
# label:  | data: 0.9652938670630736 | operation: tanh | grad: 0.0
# label:  | data: 0.9750895857650964 | operation: tanh | grad: 0.0
# label:  | data: -0.9823344009453816 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008569599009238028
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 497
# predictions:
# label:  | data: -0.9641177458483828 | operation: tanh | grad: 0.0
# label:  | data: 0.9653373039644153 | operation: tanh | grad: 0.0
# label:  | data: 0.9751194677258319 | operation: tanh | grad: 0.0
# label:  | data: -0.982353272072096 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008548716380659934
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 498
# predictions:
# label:  | data: -0.9641619502205898 | operation: tanh | grad: 0.0
# label:  | data: 0.9653805852622913 | operation: tanh | grad: 0.0
# label:  | data: 0.9751492443543027 | operation: tanh | grad: 0.0
# label:  | data: -0.9823720793939443 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008527933324571302
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 499
# predictions:
# label:  | data: -0.9642059969945207 | operation: tanh | grad: 0.0
# label:  | data: 0.9654237118712925 | operation: tanh | grad: 0.0
# label:  | data: 0.9751789162634119 | operation: tanh | grad: 0.0
# label:  | data: -0.9823908232739051 | operation: tanh | grad: 0.0
# epoch_loss: 0.0008507249136863048
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Even-Odd function using a Perceptron

# %%
perceptron = Perceptron(num_inputs=3)

# %%
# data_point1 = [1, 1, 1]  => sum = 3 (odd)  => target = -1
# data_point2 = [0, 2, 4]  => sum = 6 (even) => target = 1
# data_point3 = [-2, 4, 2] => sum = 4 (even) => target = 1
# data_point4 = [3, 1, 3]  => sum = 7 (odd)  => target = -1
inputs1_copy = [[1, 1, 1], [0, 2, 4], [-2, 4, 2], [3, 1, 5]]
targets1_copy = [-1, 1, 1, -1]

# %%
initial_predictions1_copy = [perceptron(input) for input in inputs1_copy]
initial_predictions1_copy
# Out:
# [label:  | data: 0.8560599376576918 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9929215849128291 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9991924732353679 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9869412952746284 | operation: tanh | grad: 0.0]

# %%
# Perceptron also performs well on this simple dataset. The predictions are very close to the targets.
# However, the previous model was slightly better than the perceptron model. This is expected as the previous
# model was a neural network with 2 hidden layers. The perceptron model is a single neuron model.
num_epochs = 500
for epoch in range(num_epochs):
    print(f"epoch: {epoch}")
    predictions = []
    for input in inputs1_copy:
        predictions.append(perceptron(input))
    print("predictions:")
    for prediction in predictions:
        print(prediction)
    epoch_loss = mean_squared_error(predictions, targets1_copy)
    
    # The gradients should always be zeroed out before each backpropagation step.
    # Otherwise, the gradients from previous epoch will accumulate.
    zero_gradients(model=perceptron)
    epoch_loss.backward()
    update_parameters(model=perceptron, learning_rate=0.1)
    print(f"epoch_loss: {epoch_loss.data}")
    print("-" * 150)
# Out:
# epoch: 0
# predictions:
# label:  | data: 0.8560599376576918 | operation: tanh | grad: 0.0
# label:  | data: 0.9929215849128291 | operation: tanh | grad: 0.0
# label:  | data: 0.9991924732353679 | operation: tanh | grad: 0.0
# label:  | data: 0.9869412952746284 | operation: tanh | grad: 0.0
# epoch_loss: 1.8482362397762788
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 1
# predictions:
# label:  | data: 0.8189074109515043 | operation: tanh | grad: 0.0
# label:  | data: 0.9887493488787276 | operation: tanh | grad: 0.0
# label:  | data: 0.9989164496204915 | operation: tanh | grad: 0.0
# label:  | data: 0.9743553517948288 | operation: tanh | grad: 0.0
# epoch_loss: 1.8016577440018162
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 2
# predictions:
# label:  | data: 0.7546939057774749 | operation: tanh | grad: 0.0
# label:  | data: 0.9785852393855098 | operation: tanh | grad: 0.0
# label:  | data: 0.9984014683412382 | operation: tanh | grad: 0.0
# label:  | data: 0.9344800251264663 | operation: tanh | grad: 0.0
# epoch_loss: 1.705406204465386
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 3
# predictions:
# label:  | data: 0.6109516597840394 | operation: tanh | grad: 0.0
# label:  | data: 0.9375815523747013 | operation: tanh | grad: 0.0
# label:  | data: 0.9970986055655942 | operation: tanh | grad: 0.0
# label:  | data: 0.7037446355017455 | operation: tanh | grad: 0.0
# epoch_loss: 1.375453878463886
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 4
# predictions:
# label:  | data: 0.08100091259328827 | operation: tanh | grad: 0.0
# label:  | data: 0.36555724542092927 | operation: tanh | grad: 0.0
# label:  | data: 0.9897486428542474 | operation: tanh | grad: 0.0
# label:  | data: -0.8240700138421171 | operation: tanh | grad: 0.0
# epoch_loss: 0.4005342580545609
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 5
# predictions:
# label:  | data: 0.030592400961830118 | operation: tanh | grad: 0.0
# label:  | data: 0.4775557072287836 | operation: tanh | grad: 0.0
# label:  | data: 0.9927446844330473 | operation: tanh | grad: 0.0
# label:  | data: -0.8261046110593087 | operation: tanh | grad: 0.0
# epoch_loss: 0.34134024546707414
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 6
# predictions:
# label:  | data: -0.061675784412400035 | operation: tanh | grad: 0.0
# label:  | data: 0.4773058292153321 | operation: tanh | grad: 0.0
# label:  | data: 0.9935711462552979 | operation: tanh | grad: 0.0
# label:  | data: -0.8682970636454362 | operation: tanh | grad: 0.0
# epoch_loss: 0.2927621308338103
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 7
# predictions:
# label:  | data: -0.12299729998881716 | operation: tanh | grad: 0.0
# label:  | data: 0.5218811422988459 | operation: tanh | grad: 0.0
# label:  | data: 0.9946796092688711 | operation: tanh | grad: 0.0
# label:  | data: -0.8826492610570524 | operation: tanh | grad: 0.0
# epoch_loss: 0.2528827201010872
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 8
# predictions:
# label:  | data: -0.18538617259096504 | operation: tanh | grad: 0.0
# label:  | data: 0.5456319761227636 | operation: tanh | grad: 0.0
# label:  | data: 0.995356266541133 | operation: tanh | grad: 0.0
# label:  | data: -0.8988232553574074 | operation: tanh | grad: 0.0
# epoch_loss: 0.22007607171125285
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 9
# predictions:
# label:  | data: -0.23823562751117222 | operation: tanh | grad: 0.0
# label:  | data: 0.5713726662362831 | operation: tanh | grad: 0.0
# label:  | data: 0.9959283968429672 | operation: tanh | grad: 0.0
# label:  | data: -0.9099746360601192 | operation: tanh | grad: 0.0
# epoch_loss: 0.1930318736368667
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 10
# predictions:
# label:  | data: -0.2851665007090431 | operation: tanh | grad: 0.0
# label:  | data: 0.5937443100506575 | operation: tanh | grad: 0.0
# label:  | data: 0.9963795608884456 | operation: tanh | grad: 0.0
# label:  | data: -0.9189900092825394 | operation: tanh | grad: 0.0
# epoch_loss: 0.17065158587504353
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 11
# predictions:
# label:  | data: -0.3264635320595427 | operation: tanh | grad: 0.0
# label:  | data: 0.6139971149692144 | operation: tanh | grad: 0.0
# label:  | data: 0.9967481087972863 | operation: tanh | grad: 0.0
# label:  | data: -0.9262047404686462 | operation: tanh | grad: 0.0
# epoch_loss: 0.1520264790058727
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 12
# predictions:
# label:  | data: -0.36295559883655415 | operation: tanh | grad: 0.0
# label:  | data: 0.6322529846021756 | operation: tanh | grad: 0.0
# label:  | data: 0.9970528676587486 | operation: tanh | grad: 0.0
# label:  | data: -0.9321046586597832 | operation: tanh | grad: 0.0
# epoch_loss: 0.13642047483811062
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 13
# predictions:
# label:  | data: -0.395327988163517 | operation: tanh | grad: 0.0
# label:  | data: 0.6487397746144287 | operation: tanh | grad: 0.0
# label:  | data: 0.9973081411096087 | operation: tanh | grad: 0.0
# label:  | data: -0.9370060742845897 | operation: tanh | grad: 0.0
# epoch_loss: 0.12324686715440664
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 14
# predictions:
# label:  | data: -0.42417615734323855 | operation: tanh | grad: 0.0
# label:  | data: 0.6636628929709928 | operation: tanh | grad: 0.0
# label:  | data: 0.9975244056332887 | operation: tanh | grad: 0.0
# label:  | data: -0.9411364304426552 | operation: tanh | grad: 0.0
# epoch_loss: 0.11204169893128538
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 15
# predictions:
# label:  | data: -0.450005997596296 | operation: tanh | grad: 0.0
# label:  | data: 0.6772078552389961 | operation: tanh | grad: 0.0
# label:  | data: 0.9977095035343867 | operation: tanh | grad: 0.0
# label:  | data: -0.9446613660375683 | operation: tanh | grad: 0.0
# epoch_loss: 0.10243894554558536
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 16
# predictions:
# label:  | data: -0.4732434225525406 | operation: tanh | grad: 0.0
# label:  | data: 0.6895393243008745 | operation: tanh | grad: 0.0
# label:  | data: 0.9978693968674782 | operation: tanh | grad: 0.0
# label:  | data: -0.9477036187506753 | operation: tanh | grad: 0.0
# epoch_loss: 0.09414944350030048
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 17
# predictions:
# label:  | data: -0.4942457012440608 | operation: tanh | grad: 0.0
# label:  | data: 0.7008017460769262 | operation: tanh | grad: 0.0
# label:  | data: 0.9980086804458096 | operation: tanh | grad: 0.0
# label:  | data: -0.9503556475015024 | operation: tanh | grad: 0.0
# epoch_loss: 0.08694388323732247
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 18
# predictions:
# label:  | data: -0.5133124190105125 | operation: tanh | grad: 0.0
# label:  | data: 0.7111209137529374 | operation: tanh | grad: 0.0
# label:  | data: 0.9981309393754679 | operation: tanh | grad: 0.0
# label:  | data: -0.952688183583745 | operation: tanh | grad: 0.0
# epoch_loss: 0.08063945733014011
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 19
# predictions:
# label:  | data: -0.5306952238781667 | operation: tanh | grad: 0.0
# label:  | data: 0.7206059403836635 | operation: tanh | grad: 0.0
# label:  | data: 0.9982390028797906 | operation: tanh | grad: 0.0
# label:  | data: -0.9547561152818881 | operation: tanh | grad: 0.0
# epoch_loss: 0.07508953091372607
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 20
# predictions:
# label:  | data: -0.5466061321510127 | operation: tanh | grad: 0.0
# label:  | data: 0.7293513140513884 | operation: tanh | grad: 0.0
# label:  | data: 0.9983351272892518 | operation: tanh | grad: 0.0
# label:  | data: -0.9566026020132022 | operation: tanh | grad: 0.0
# epoch_loss: 0.07017570414048566
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 21
# predictions:
# label:  | data: -0.5612244451847209 | operation: tanh | grad: 0.0
# label:  | data: 0.7374388562103711 | operation: tanh | grad: 0.0
# label:  | data: 0.998421129755126 | operation: tanh | grad: 0.0
# label:  | data: -0.9582619954057289 | operation: tanh | grad: 0.0
# epoch_loss: 0.06580172389758393
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 22
# predictions:
# label:  | data: -0.5747024382216233 | operation: tanh | grad: 0.0
# label:  | data: 0.7449394981562693 | operation: tanh | grad: 0.0
# label:  | data: 0.9984984871582147 | operation: tanh | grad: 0.0
# label:  | data: -0.9597619442096418 | operation: tanh | grad: 0.0
# epoch_loss: 0.0618888078325025
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 23
# predictions:
# label:  | data: -0.5871700100244132 | operation: tanh | grad: 0.0
# label:  | data: 0.7519148460424685 | operation: tanh | grad: 0.0
# label:  | data: 0.9985684101046673 | operation: tanh | grad: 0.0
# label:  | data: -0.9611249325278347 | operation: tanh | grad: 0.0
# epoch_loss: 0.058372041139492264
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 24
# predictions:
# label:  | data: -0.5987384738549238 | operation: tanh | grad: 0.0
# label:  | data: 0.758418535067725 | operation: tanh | grad: 0.0
# label:  | data: 0.9986318988731379 | operation: tanh | grad: 0.0
# label:  | data: -0.962369418901281 | operation: tanh | grad: 0.0
# epoch_loss: 0.055197587224405056
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 25
# predictions:
# label:  | data: -0.6095036483455618 | operation: tanh | grad: 0.0
# label:  | data: 0.764497388360321 | operation: tanh | grad: 0.0
# label:  | data: 0.9986897861393706 | operation: tanh | grad: 0.0
# label:  | data: -0.9635106903686564 | operation: tanh | grad: 0.0
# epoch_loss: 0.05232051678056719
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 26
# predictions:
# label:  | data: -0.6195483815336666 | operation: tanh | grad: 0.0
# label:  | data: 0.7701924022052117 | operation: tanh | grad: 0.0
# label:  | data: 0.9987427699118153 | operation: tanh | grad: 0.0
# label:  | data: -0.9645615103214373 | operation: tanh | grad: 0.0
# epoch_loss: 0.04970310829401397
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 27
# predictions:
# label:  | data: -0.6289446173971261 | operation: tanh | grad: 0.0
# label:  | data: 0.7755395806049228 | operation: tanh | grad: 0.0
# label:  | data: 0.9987914391481664 | operation: tanh | grad: 0.0
# label:  | data: -0.9655326153281227 | operation: tanh | grad: 0.0
# epoch_loss: 0.0473135095147577
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 28
# predictions:
# label:  | data: -0.6377550933711148 | operation: tanh | grad: 0.0
# label:  | data: 0.7805706410876426 | operation: tanh | grad: 0.0
# label:  | data: 0.9988362938479294 | operation: tanh | grad: 0.0
# label:  | data: -0.966433100044801 | operation: tanh | grad: 0.0
# epoch_loss: 0.04512467672896715
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 29
# predictions:
# label:  | data: -0.6460347399093315 | operation: tanh | grad: 0.0
# label:  | data: 0.7853136115147356 | operation: tanh | grad: 0.0
# label:  | data: 0.9988777609385118 | operation: tanh | grad: 0.0
# label:  | data: -0.9672707182845809 | operation: tanh | grad: 0.0
# epoch_loss: 0.04311352901350473
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 30
# predictions:
# label:  | data: -0.6538318389570937 | operation: tanh | grad: 0.0
# label:  | data: 0.7897933351255391 | operation: tanh | grad: 0.0
# label:  | data: 0.9989162069308306 | operation: tanh | grad: 0.0
# label:  | data: -0.9680521206257051 | operation: tanh | grad: 0.0
# epoch_loss: 0.041260269820350665
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 31
# predictions:
# label:  | data: -0.6611889867924682 | operation: tanh | grad: 0.0
# label:  | data: 0.794031898568093 | operation: tanh | grad: 0.0
# label:  | data: 0.9989519480738845 | operation: tanh | grad: 0.0
# label:  | data: -0.9687830435158102 | operation: tanh | grad: 0.0
# epoch_loss: 0.03954783956578856
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 32
# predictions:
# label:  | data: -0.6681438975906727 | operation: tanh | grad: 0.0
# label:  | data: 0.7980489953791537 | operation: tanh | grad: 0.0
# label:  | data: 0.9989852585581136 | operation: tanh | grad: 0.0
# label:  | data: -0.9694684609640631 | operation: tanh | grad: 0.0
# epoch_loss: 0.037961471387443955
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 33
# predictions:
# label:  | data: -0.6747300768376717 | operation: tanh | grad: 0.0
# label:  | data: 0.8018622353645992 | operation: tanh | grad: 0.0
# label:  | data: 0.9990163771853328 | operation: tanh | grad: 0.0
# label:  | data: -0.9701127071269496 | operation: tanh | grad: 0.0
# epoch_loss: 0.03648832861946536
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 34
# predictions:
# label:  | data: -0.6809773879849538 | operation: tanh | grad: 0.0
# label:  | data: 0.8054874086034908 | operation: tanh | grad: 0.0
# label:  | data: 0.9990455128251505 | operation: tanh | grad: 0.0
# label:  | data: -0.9707195760649704 | operation: tanh | grad: 0.0
# epoch_loss: 0.03511720736506752
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 35
# predictions:
# label:  | data: -0.6869125311888261 | operation: tanh | grad: 0.0
# label:  | data: 0.808938711338664 | operation: tanh | grad: 0.0
# label:  | data: 0.9990728489046732 | operation: tanh | grad: 0.0
# label:  | data: -0.971292403456025 | operation: tanh | grad: 0.0
# epoch_loss: 0.03383829121500083
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 36
# predictions:
# label:  | data: -0.6925594493642918 | operation: tanh | grad: 0.0
# label:  | data: 0.8122289397946731 | operation: tanh | grad: 0.0
# label:  | data: 0.9990985471232144 | operation: tanh | grad: 0.0
# label:  | data: -0.9718341339444435 | operation: tanh | grad: 0.0
# epoch_loss: 0.03264294796344214
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 37
# predictions:
# label:  | data: -0.6979396739072188 | operation: tanh | grad: 0.0
# label:  | data: 0.8153696569477104 | operation: tanh | grad: 0.0
# label:  | data: 0.9991227505419633 | operation: tanh | grad: 0.0
# label:  | data: -0.9723473769760093 | operation: tanh | grad: 0.0
# epoch_loss: 0.03152356032540051
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 38
# predictions:
# label:  | data: -0.7030726201425891 | operation: tanh | grad: 0.0
# label:  | data: 0.8183713364302787 | operation: tanh | grad: 0.0
# label:  | data: 0.9991455861666496 | operation: tanh | grad: 0.0
# label:  | data: -0.9728344533437653 | operation: tanh | grad: 0.0
# epoch_loss: 0.03047338432181022
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 39
# predictions:
# label:  | data: -0.7079758407183502 | operation: tanh | grad: 0.0
# label:  | data: 0.82124348705735 | operation: tanh | grad: 0.0
# label:  | data: 0.9991671671166965 | operation: tanh | grad: 0.0
# label:  | data: -0.9732974341934163 | operation: tanh | grad: 0.0
# epoch_loss: 0.029486430288709158
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 40
# predictions:
# label:  | data: -0.7126652436876598 | operation: tanh | grad: 0.0
# label:  | data: 0.8239947608856829 | operation: tanh | grad: 0.0
# label:  | data: 0.9991875944553448 | operation: tanh | grad: 0.0
# label:  | data: -0.9737381738721866 | operation: tanh | grad: 0.0
# epoch_loss: 0.028557362473774085
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 41
# predictions:
# label:  | data: -0.7171552808318677 | operation: tanh | grad: 0.0
# label:  | data: 0.8266330472427719 | operation: tanh | grad: 0.0
# label:  | data: 0.9992069587404255 | operation: tanh | grad: 0.0
# label:  | data: -0.9741583377231811 | operation: tanh | grad: 0.0
# epoch_loss: 0.02768141397332378
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 42
# predictions:
# label:  | data: -0.7214591108134486 | operation: tanh | grad: 0.0
# label:  | data: 0.8291655547688748 | operation: tanh | grad: 0.0
# label:  | data: 0.9992253413438555 | operation: tanh | grad: 0.0
# label:  | data: -0.9745594257081982 | operation: tanh | grad: 0.0
# epoch_loss: 0.026854314385647816
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 43
# predictions:
# label:  | data: -0.7255887409660777 | operation: tanh | grad: 0.0
# label:  | data: 0.83159888319009 | operation: tanh | grad: 0.0
# label:  | data: 0.9992428155787793 | operation: tanh | grad: 0.0
# label:  | data: -0.974942792570466 | operation: tanh | grad: 0.0
# epoch_loss: 0.026072228049955442
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 44
# predictions:
# label:  | data: -0.7295551508917124 | operation: tanh | grad: 0.0
# label:  | data: 0.8339390862704292 | operation: tanh | grad: 0.0
# label:  | data: 0.9992594476660297 | operation: tanh | grad: 0.0
# label:  | data: -0.9753096651137593 | operation: tanh | grad: 0.0
# epoch_loss: 0.02533170113311461
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 45
# predictions:
# label:  | data: -0.7333684005132853 | operation: tanh | grad: 0.0
# label:  | data: 0.8361917271663993 | operation: tanh | grad: 0.0
# label:  | data: 0.9992752975658084 | operation: tanh | grad: 0.0
# label:  | data: -0.9756611570673918 | operation: tanh | grad: 0.0
# epoch_loss: 0.02462961614062187
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 46
# predictions:
# label:  | data: -0.7370377248037386 | operation: tanh | grad: 0.0
# label:  | data: 0.838361927220631 | operation: tanh | grad: 0.0
# label:  | data: 0.9992904196958511 | operation: tanh | grad: 0.0
# label:  | data: -0.9759982819213959 | operation: tanh | grad: 0.0
# epoch_loss: 0.023963152680788927
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 47
# predictions:
# label:  | data: -0.7405716170596409 | operation: tanh | grad: 0.0
# label:  | data: 0.8404544090750046 | operation: tanh | grad: 0.0
# label:  | data: 0.999304863553625 | operation: tanh | grad: 0.0
# label:  | data: -0.9763219640479477 | operation: tanh | grad: 0.0
# epoch_loss: 0.023329753514970335
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 48
# predictions:
# label:  | data: -0.7439779022962963 | operation: tanh | grad: 0.0
# label:  | data: 0.8424735348530636 | operation: tanh | grad: 0.0
# label:  | data: 0.9993186742570932 | operation: tanh | grad: 0.0
# label:  | data: -0.9766330483701724 | operation: tanh | grad: 0.0
# epoch_loss: 0.022727095091883094
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 49
# predictions:
# label:  | data: -0.7472638020995536 | operation: tanh | grad: 0.0
# label:  | data: 0.8444233400519107 | operation: tanh | grad: 0.0
# label:  | data: 0.9993318930161318 | operation: tanh | grad: 0.0
# label:  | data: -0.9769323087950169 | operation: tanh | grad: 0.0
# epoch_loss: 0.022153061898561848
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 50
# predictions:
# label:  | data: -0.7504359920684237 | operation: tanh | grad: 0.0
# label:  | data: 0.8463075636915781 | operation: tanh | grad: 0.0
# label:  | data: 0.9993445575446958 | operation: tanh | grad: 0.0
# label:  | data: -0.9772204555907429 | operation: tanh | grad: 0.0
# epoch_loss: 0.02160572407039893
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 51
# predictions:
# label:  | data: -0.753500652814678 | operation: tanh | grad: 0.0
# label:  | data: 0.8481296751921453 | operation: tanh | grad: 0.0
# label:  | data: 0.9993567024221908 | operation: tanh | grad: 0.0
# label:  | data: -0.9774981418600953 | operation: tanh | grad: 0.0
# epoch_loss: 0.021083317792888794
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 52
# predictions:
# label:  | data: -0.7564635153449543 | operation: tanh | grad: 0.0
# label:  | data: 0.8498928983831584 | operation: tanh | grad: 0.0
# label:  | data: 0.9993683594111643 | operation: tanh | grad: 0.0
# label:  | data: -0.9777659692360069 | operation: tanh | grad: 0.0
# epoch_loss: 0.02058422810194845
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 53
# predictions:
# label:  | data: -0.7593299015327144 | operation: tanh | grad: 0.0
# label:  | data: 0.8516002329942377 | operation: tanh | grad: 0.0
# label:  | data: 0.9993795577373225 | operation: tanh | grad: 0.0
# label:  | data: -0.9780244929067627 | operation: tanh | grad: 0.0
# epoch_loss: 0.02010697375105593
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 54
# predictions:
# label:  | data: -0.762104760287831 | operation: tanh | grad: 0.0
# label:  | data: 0.8532544739284537 | operation: tanh | grad: 0.0
# label:  | data: 0.9993903243369548 | operation: tanh | grad: 0.0
# label:  | data: -0.9782742260610782 | operation: tanh | grad: 0.0
# epoch_loss: 0.019650193864346115
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 55
# predictions:
# label:  | data: -0.7647926999473773 | operation: tanh | grad: 0.0
# label:  | data: 0.8548582285797751 | operation: tanh | grad: 0.0
# label:  | data: 0.9994006840760872 | operation: tanh | grad: 0.0
# label:  | data: -0.9785156438298621 | operation: tanh | grad: 0.0
# epoch_loss: 0.019212636137166825
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 56
# predictions:
# label:  | data: -0.7673980173398858 | operation: tanh | grad: 0.0
# label:  | data: 0.8564139324215139 | operation: tanh | grad: 0.0
# label:  | data: 0.9994106599450416 | operation: tanh | grad: 0.0
# label:  | data: -0.9787491867900389 | operation: tanh | grad: 0.0
# epoch_loss: 0.018793146380963674
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 57
# predictions:
# label:  | data: -0.7699247239146753 | operation: tanh | grad: 0.0
# label:  | data: 0.8579238630632685 | operation: tanh | grad: 0.0
# label:  | data: 0.9994202732315515 | operation: tanh | grad: 0.0
# label:  | data: -0.9789752640862743 | operation: tanh | grad: 0.0
# epoch_loss: 0.018390659238992812
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 58
# predictions:
# label:  | data: -0.7723765692761726 | operation: tanh | grad: 0.0
# label:  | data: 0.8593901529486402 | operation: tanh | grad: 0.0
# label:  | data: 0.9994295436751236 | operation: tanh | grad: 0.0
# label:  | data: -0.9791942562184568 | operation: tanh | grad: 0.0
# epoch_loss: 0.018004189924253417
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 59
# predictions:
# label:  | data: -0.7747570624189993 | operation: tanh | grad: 0.0
# label:  | data: 0.8608148008443071 | operation: tanh | grad: 0.0
# label:  | data: 0.9994384896049707 | operation: tanh | grad: 0.0
# label:  | data: -0.9794065175360458 | operation: tanh | grad: 0.0
# epoch_loss: 0.017632826852011344
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 60
# predictions:
# label:  | data: -0.7770694909217472 | operation: tanh | grad: 0.0
# label:  | data: 0.8621996822523573 | operation: tanh | grad: 0.0
# label:  | data: 0.9994471280635039 | operation: tanh | grad: 0.0
# label:  | data: -0.979612378474729 | operation: tanh | grad: 0.0
# epoch_loss: 0.017275725057019027
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 61
# predictions:
# label:  | data: -0.7793169383248867 | operation: tanh | grad: 0.0
# label:  | data: 0.863546558861647 | operation: tanh | grad: 0.0
# label:  | data: 0.9994554749171168 | operation: tanh | grad: 0.0
# label:  | data: -0.9798121475659958 | operation: tanh | grad: 0.0
# epoch_loss: 0.016932100300565713
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 62
# predictions:
# label:  | data: -0.781502299890274 | operation: tanh | grad: 0.0
# label:  | data: 0.8648570871399975 | operation: tanh | grad: 0.0
# label:  | data: 0.9994635449557542 | operation: tanh | grad: 0.0
# label:  | data: -0.9800061132461605 | operation: tanh | grad: 0.0
# epoch_loss: 0.016601223785266458
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 63
# predictions:
# label:  | data: -0.7836282969155848 | operation: tanh | grad: 0.0
# label:  | data: 0.8661328261569313 | operation: tanh | grad: 0.0
# label:  | data: 0.9994713519825611 | operation: tanh | grad: 0.0
# label:  | data: -0.9801945454878674 | operation: tanh | grad: 0.0
# epoch_loss: 0.0162824174063848
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 64
# predictions:
# label:  | data: -0.78569748975613 | operation: tanh | grad: 0.0
# label:  | data: 0.8673752447161416 | operation: tanh | grad: 0.0
# label:  | data: 0.9994789088947451 | operation: tanh | grad: 0.0
# label:  | data: -0.9803776972741408 | operation: tanh | grad: 0.0
# epoch_loss: 0.015975049477783144
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 65
# predictions:
# label:  | data: -0.7877122896884109 | operation: tanh | grad: 0.0
# label:  | data: 0.8685857278677259 | operation: tanh | grad: 0.0
# label:  | data: 0.9994862277566374 | operation: tanh | grad: 0.0
# label:  | data: -0.9805558059324824 | operation: tanh | grad: 0.0
# epoch_loss: 0.015678530878561477
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 66
# predictions:
# label:  | data: -0.7896749697340519 | operation: tanh | grad: 0.0
# label:  | data: 0.8697655828622324 | operation: tanh | grad: 0.0
# label:  | data: 0.999493319865809 | operation: tanh | grad: 0.0
# label:  | data: -0.9807290943443348 | operation: tanh | grad: 0.0
# epoch_loss: 0.015392311573283492
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 67
# predictions:
# label:  | data: -0.7915876745490681 | operation: tanh | grad: 0.0
# label:  | data: 0.870916044601584 | operation: tanh | grad: 0.0
# label:  | data: 0.9995001958130054 | operation: tanh | grad: 0.0
# label:  | data: -0.9808977720433303 | operation: tanh | grad: 0.0
# epoch_loss: 0.015115877464574832
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 68
# predictions:
# label:  | data: -0.79345242947148 | operation: tanh | grad: 0.0
# label:  | data: 0.872038280635839 | operation: tanh | grad: 0.0
# label:  | data: 0.9995068655365562 | operation: tanh | grad: 0.0
# label:  | data: -0.9810620362141199 | operation: tanh | grad: 0.0
# epoch_loss: 0.014848747541955148
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 69
# predictions:
# label:  | data: -0.7952711488098732 | operation: tanh | grad: 0.0
# label:  | data: 0.8731333957493742 | operation: tanh | grad: 0.0
# label:  | data: 0.9995133383718444 | operation: tanh | grad: 0.0
# label:  | data: -0.9812220726021738 | operation: tanh | grad: 0.0
# epoch_loss: 0.01459047129515309
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 70
# predictions:
# label:  | data: -0.7970456434463422 | operation: tanh | grad: 0.0
# label:  | data: 0.874202436175378 | operation: tanh | grad: 0.0
# label:  | data: 0.9995196230963517 | operation: tanh | grad: 0.0
# label:  | data: -0.9813780563437002 | operation: tanh | grad: 0.0
# epoch_loss: 0.01434062636395677
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 71
# predictions:
# label:  | data: -0.7987776278192616 | operation: tanh | grad: 0.0
# label:  | data: 0.875246393473383 | operation: tanh | grad: 0.0
# label:  | data: 0.9995257279707289 | operation: tanh | grad: 0.0
# label:  | data: -0.9815301527237923 | operation: tanh | grad: 0.0
# epoch_loss: 0.014098816399951438
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 72
# predictions:
# label:  | data: -0.8004687263442687 | operation: tanh | grad: 0.0
# label:  | data: 0.8762662081009127 | operation: tanh | grad: 0.0
# label:  | data: 0.9995316607763022 | operation: tanh | grad: 0.0
# label:  | data: -0.9816785178699634 | operation: tanh | grad: 0.0
# epoch_loss: 0.013864669118368669
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 73
# predictions:
# label:  | data: -0.8021204793256482 | operation: tanh | grad: 0.0
# label:  | data: 0.8772627727070851 | operation: tanh | grad: 0.0
# label:  | data: 0.9995374288493557 | operation: tanh | grad: 0.0
# label:  | data: -0.9818232993874384 | operation: tanh | grad: 0.0
# epoch_loss: 0.013637834520772996
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 74
# predictions:
# label:  | data: -0.8037343484048274 | operation: tanh | grad: 0.0
# label:  | data: 0.8782369351731611 | operation: tanh | grad: 0.0
# label:  | data: 0.9995430391125268 | operation: tanh | grad: 0.0
# label:  | data: -0.9819646369418474 | operation: tanh | grad: 0.0
# epoch_loss: 0.013417983271498677
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 75
# predictions:
# label:  | data: -0.8053117215878629 | operation: tanh | grad: 0.0
# label:  | data: 0.8791895014224873 | operation: tanh | grad: 0.0
# label:  | data: 0.9995484981035777 | operation: tanh | grad: 0.0
# label:  | data: -0.9821026627943653 | operation: tanh | grad: 0.0
# epoch_loss: 0.013204805212660918
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 76
# predictions:
# label:  | data: -0.8068539178895138 | operation: tanh | grad: 0.0
# label:  | data: 0.8801212380200322 | operation: tanh | grad: 0.0
# label:  | data: 0.9995538120018005 | operation: tanh | grad: 0.0
# label:  | data: -0.9822375022937763 | operation: tanh | grad: 0.0
# epoch_loss: 0.012998008004243453
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 77
# predictions:
# label:  | data: -0.8083621916277088 | operation: tanh | grad: 0.0
# label:  | data: 0.8810328745797305 | operation: tanh | grad: 0.0
# label:  | data: 0.999558986652286 | operation: tanh | grad: 0.0
# label:  | data: -0.9823692743294776 | operation: tanh | grad: 0.0
# epoch_loss: 0.012797315877234802
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 78
# predictions:
# label:  | data: -0.8098377363988387 | operation: tanh | grad: 0.0
# label:  | data: 0.8819251059960493 | operation: tanh | grad: 0.0
# label:  | data: 0.999564027588241 | operation: tanh | grad: 0.0
# label:  | data: -0.9824980917490139 | operation: tanh | grad: 0.0
# epoch_loss: 0.012602468489082872
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 79
# predictions:
# label:  | data: -0.8112816887613158 | operation: tanh | grad: 0.0
# label:  | data: 0.8827985945146243 | operation: tanh | grad: 0.0
# label:  | data: 0.9995689400515491 | operation: tanh | grad: 0.0
# label:  | data: -0.9826240617433479 | operation: tanh | grad: 0.0
# epoch_loss: 0.012413219871876621
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 80
# predictions:
# label:  | data: -0.8126951316521739 | operation: tanh | grad: 0.0
# label:  | data: 0.8836539716553854 | operation: tanh | grad: 0.0
# label:  | data: 0.9995737290117221 | operation: tanh | grad: 0.0
# label:  | data: -0.9827472862027642 | operation: tanh | grad: 0.0
# epoch_loss: 0.01222933746467178
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 81
# predictions:
# label:  | data: -0.8140790975590968 | operation: tanh | grad: 0.0
# label:  | data: 0.8844918400003297 | operation: tanh | grad: 0.0
# label:  | data: 0.9995783991833934 | operation: tanh | grad: 0.0
# label:  | data: -0.9828678620459885 | operation: tanh | grad: 0.0
# epoch_loss: 0.012050601222268285
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 82
# predictions:
# label:  | data: -0.8154345714681485 | operation: tanh | grad: 0.0
# label:  | data: 0.8853127748569684 | operation: tanh | grad: 0.0
# label:  | data: 0.9995829550424826 | operation: tanh | grad: 0.0
# label:  | data: -0.9829858815248637 | operation: tanh | grad: 0.0
# epoch_loss: 0.01187680279353425
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 83
# predictions:
# label:  | data: -0.816762493605566 | operation: tanh | grad: 0.0
# label:  | data: 0.8861173258074541 | operation: tanh | grad: 0.0
# label:  | data: 0.9995874008411436 | operation: tanh | grad: 0.0
# label:  | data: -0.9831014325066827 | operation: tanh | grad: 0.0
# epoch_loss: 0.01170774476307198
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 84
# predictions:
# label:  | data: -0.818063761990282 | operation: tanh | grad: 0.0
# label:  | data: 0.8869060181524868 | operation: tanh | grad: 0.0
# label:  | data: 0.9995917406216026 | operation: tanh | grad: 0.0
# label:  | data: -0.9832145987360803 | operation: tanh | grad: 0.0
# epoch_loss: 0.011543239950641316
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 85
# predictions:
# label:  | data: -0.8193392348123142 | operation: tanh | grad: 0.0
# label:  | data: 0.8876793542582762 | operation: tanh | grad: 0.0
# label:  | data: 0.9995959782289858 | operation: tanh | grad: 0.0
# label:  | data: -0.9833254600781944 | operation: tanh | grad: 0.0
# epoch_loss: 0.01138311076330833
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 86
# predictions:
# label:  | data: -0.8205897326507864 | operation: tanh | grad: 0.0
# label:  | data: 0.8884378148140997 | operation: tanh | grad: 0.0
# label:  | data: 0.9996001173232139 | operation: tanh | grad: 0.0
# label:  | data: -0.9834340927446537 | operation: tanh | grad: 0.0
# epoch_loss: 0.011227188595779338
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 87
# predictions:
# label:  | data: -0.8218160405441154 | operation: tanh | grad: 0.0
# label:  | data: 0.8891818600073355 | operation: tanh | grad: 0.0
# label:  | data: 0.999604161390047 | operation: tanh | grad: 0.0
# label:  | data: -0.9835405695038 | operation: tanh | grad: 0.0
# epoch_loss: 0.011075313274818624
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 88
# predictions:
# label:  | data: -0.823018909923787 | operation: tanh | grad: 0.0
# label:  | data: 0.8899119306222443 | operation: tanh | grad: 0.0
# label:  | data: 0.999608113751349 | operation: tanh | grad: 0.0
# label:  | data: -0.9836449598764128 | operation: tanh | grad: 0.0
# epoch_loss: 0.010927332544040548
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 89
# predictions:
# label:  | data: -0.8241990604221425 | operation: tanh | grad: 0.0
# label:  | data: 0.8906284490682391 | operation: tanh | grad: 0.0
# label:  | data: 0.9996119775746329 | operation: tanh | grad: 0.0
# label:  | data: -0.9837473303181081 | operation: tanh | grad: 0.0
# epoch_loss: 0.010783101585716883
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 90
# predictions:
# label:  | data: -0.8253571815636992 | operation: tanh | grad: 0.0
# label:  | data: 0.8913318203428888 | operation: tanh | grad: 0.0
# label:  | data: 0.9996157558819481 | operation: tanh | grad: 0.0
# label:  | data: -0.9838477443894523 | operation: tanh | grad: 0.0
# epoch_loss: 0.010642482576553912
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 91
# predictions:
# label:  | data: -0.8264939343487084 | operation: tanh | grad: 0.0
# label:  | data: 0.8920224329344605 | operation: tanh | grad: 0.0
# label:  | data: 0.9996194515581591 | operation: tanh | grad: 0.0
# label:  | data: -0.9839462629147614 | operation: tanh | grad: 0.0
# epoch_loss: 0.010505344274675484
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 92
# predictions:
# label:  | data: -0.8276099527369146 | operation: tanh | grad: 0.0
# label:  | data: 0.8927006596684063 | operation: tanh | grad: 0.0
# label:  | data: 0.9996230673586641 | operation: tanh | grad: 0.0
# label:  | data: -0.9840429441304508 | operation: tanh | grad: 0.0
# epoch_loss: 0.010371561635300999
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 93
# predictions:
# label:  | data: -0.8287058450388186 | operation: tanh | grad: 0.0
# label:  | data: 0.8933668585018308 | operation: tanh | grad: 0.0
# label:  | data: 0.9996266059166006 | operation: tanh | grad: 0.0
# label:  | data: -0.9841378438237418 | operation: tanh | grad: 0.0
# epoch_loss: 0.010241015452833829
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 94
# predictions:
# label:  | data: -0.8297821952211378 | operation: tanh | grad: 0.0
# label:  | data: 0.8940213732696535 | operation: tanh | grad: 0.0
# label:  | data: 0.9996300697495732 | operation: tanh | grad: 0.0
# label:  | data: -0.9842310154624474 | operation: tanh | grad: 0.0
# epoch_loss: 0.010113592027280177
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 95
# predictions:
# label:  | data: -0.8308395641326044 | operation: tanh | grad: 0.0
# label:  | data: 0.8946645343858735 | operation: tanh | grad: 0.0
# label:  | data: 0.9996334612659413 | operation: tanh | grad: 0.0
# label:  | data: -0.9843225103165053 | operation: tanh | grad: 0.0
# epoch_loss: 0.009989182853102936
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 96
# predictions:
# label:  | data: -0.8318784906557489 | operation: tanh | grad: 0.0
# label:  | data: 0.8952966595030715 | operation: tanh | grad: 0.0
# label:  | data: 0.9996367827707001 | operation: tanh | grad: 0.0
# label:  | data: -0.9844123775718685 | operation: tanh | grad: 0.0
# epoch_loss: 0.009867684328780626
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 97
# predictions:
# label:  | data: -0.8328994927898573 | operation: tanh | grad: 0.0
# label:  | data: 0.8959180541330427 | operation: tanh | grad: 0.0
# label:  | data: 0.9996400364709869 | operation: tanh | grad: 0.0
# label:  | data: -0.9845006644373123 | operation: tanh | grad: 0.0
# epoch_loss: 0.009748997485491549
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 98
# predictions:
# label:  | data: -0.8339030686698823 | operation: tanh | grad: 0.0
# label:  | data: 0.8965290122312155 | operation: tanh | grad: 0.0
# label:  | data: 0.9996432244812372 | operation: tanh | grad: 0.0
# label:  | data: -0.9845874162446687 | operation: tanh | grad: 0.0
# epoch_loss: 0.009633027733478919
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 99
# predictions:
# label:  | data: -0.8348896975257047 | operation: tanh | grad: 0.0
# label:  | data: 0.8971298167473146 | operation: tanh | grad: 0.0
# label:  | data: 0.9996463488280196 | operation: tanh | grad: 0.0
# label:  | data: -0.9846726765429569 | operation: tanh | grad: 0.0
# epoch_loss: 0.009519684624775652
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 100
# predictions:
# label:  | data: -0.8358598405858081 | operation: tanh | grad: 0.0
# label:  | data: 0.8977207401445326 | operation: tanh | grad: 0.0
# label:  | data: 0.9996494114545688 | operation: tanh | grad: 0.0
# label:  | data: -0.9847564871868457 | operation: tanh | grad: 0.0
# epoch_loss: 0.009408881631077885
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 101
# predictions:
# label:  | data: -0.8368139419291067 | operation: tanh | grad: 0.0
# label:  | data: 0.8983020448893029 | operation: tanh | grad: 0.0
# label:  | data: 0.9996524142250411 | operation: tanh | grad: 0.0
# label:  | data: -0.984838888419844 | operation: tanh | grad: 0.0
# epoch_loss: 0.009300535935657803
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 102
# predictions:
# label:  | data: -0.8377524292883838 | operation: tanh | grad: 0.0
# label:  | data: 0.8988739839136097 | operation: tanh | grad: 0.0
# label:  | data: 0.9996553589285139 | operation: tanh | grad: 0.0
# ...
# epoch: 466
# predictions:
# label:  | data: -0.930444463226293 | operation: tanh | grad: 0.0
# label:  | data: 0.9560663980243806 | operation: tanh | grad: 0.0
# label:  | data: 0.9998995003441422 | operation: tanh | grad: 0.0
# label:  | data: -0.9929478044023029 | operation: tanh | grad: 0.0
# epoch_loss: 0.0017044694103399128
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 467
# predictions:
# label:  | data: -0.9305244466008873 | operation: tanh | grad: 0.0
# label:  | data: 0.9561163452515478 | operation: tanh | grad: 0.0
# label:  | data: 0.9998996669784208 | operation: tanh | grad: 0.0
# label:  | data: -0.9929549162285276 | operation: tanh | grad: 0.0
# epoch_loss: 0.0017005677365641498
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 468
# predictions:
# label:  | data: -0.9306041608921604 | operation: tanh | grad: 0.0
# label:  | data: 0.9561661254847125 | operation: tanh | grad: 0.0
# label:  | data: 0.9998998329655929 | operation: tanh | grad: 0.0
# label:  | data: -0.9929620048717819 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016966836123406858
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 469
# predictions:
# label:  | data: -0.9306836075920335 | operation: tanh | grad: 0.0
# label:  | data: 0.956215739645229 | operation: tanh | grad: 0.0
# label:  | data: 0.9998999983095932 | operation: tanh | grad: 0.0
# label:  | data: -0.9929690704589997 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016928169204545405
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 470
# predictions:
# label:  | data: -0.9307627881809329 | operation: tanh | grad: 0.0
# label:  | data: 0.9562651886473823 | operation: tanh | grad: 0.0
# label:  | data: 0.9999001630143233 | operation: tanh | grad: 0.0
# label:  | data: -0.9929761131161422 | operation: tanh | grad: 0.0
# epoch_loss: 0.001688967544727089
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 471
# predictions:
# label:  | data: -0.9308417041279042 | operation: tanh | grad: 0.0
# label:  | data: 0.9563144733984589 | operation: tanh | grad: 0.0
# label:  | data: 0.9999003270836532 | operation: tanh | grad: 0.0
# label:  | data: -0.9929831329682061 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016851353700046063
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 472
# predictions:
# label:  | data: -0.930920356890722 | operation: tanh | grad: 0.0
# label:  | data: 0.956363594798814 | operation: tanh | grad: 0.0
# label:  | data: 0.9999004905214207 | operation: tanh | grad: 0.0
# label:  | data: -0.9929901301392349 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016813202821471262
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 473
# predictions:
# label:  | data: -0.9309987479160011 | operation: tanh | grad: 0.0
# label:  | data: 0.9564125537419402 | operation: tanh | grad: 0.0
# label:  | data: 0.9999006533314316 | operation: tanh | grad: 0.0
# label:  | data: -0.9929971047523266 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016775221680173124
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 474
# predictions:
# label:  | data: -0.9310768786393072 | operation: tanh | grad: 0.0
# label:  | data: 0.956461351114534 | operation: tanh | grad: 0.0
# label:  | data: 0.9999008155174618 | operation: tanh | grad: 0.0
# label:  | data: -0.9930040569296443 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016737409154694773
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 475
# predictions:
# label:  | data: -0.9311547504852631 | operation: tanh | grad: 0.0
# label:  | data: 0.9565099877965616 | operation: tanh | grad: 0.0
# label:  | data: 0.9999009770832552 | operation: tanh | grad: 0.0
# label:  | data: -0.9930109867924244 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016699764133388279
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 476
# predictions:
# label:  | data: -0.9312323648676565 | operation: tanh | grad: 0.0
# label:  | data: 0.9565584646613242 | operation: tanh | grad: 0.0
# label:  | data: 0.9999011380325259 | operation: tanh | grad: 0.0
# label:  | data: -0.9930178944609865 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016662285514307696
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 477
# predictions:
# label:  | data: -0.9313097231895441 | operation: tanh | grad: 0.0
# label:  | data: 0.9566067825755239 | operation: tanh | grad: 0.0
# label:  | data: 0.9999012983689575 | operation: tanh | grad: 0.0
# label:  | data: -0.9930247800547408 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016624972205104066
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 478
# predictions:
# label:  | data: -0.9313868268433565 | operation: tanh | grad: 0.0
# label:  | data: 0.9566549423993255 | operation: tanh | grad: 0.0
# label:  | data: 0.9999014580962037 | operation: tanh | grad: 0.0
# label:  | data: -0.9930316436921984 | operation: tanh | grad: 0.0
# epoch_loss: 0.001658782312292155
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 479
# predictions:
# label:  | data: -0.9314636772110018 | operation: tanh | grad: 0.0
# label:  | data: 0.9567029449864208 | operation: tanh | grad: 0.0
# label:  | data: 0.999901617217889 | operation: tanh | grad: 0.0
# label:  | data: -0.9930384854909797 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016550837194294437
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 480
# predictions:
# label:  | data: -0.931540275663966 | operation: tanh | grad: 0.0
# label:  | data: 0.9567507911840911 | operation: tanh | grad: 0.0
# label:  | data: 0.9999017757376081 | operation: tanh | grad: 0.0
# label:  | data: -0.9930453055678218 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016514013355046367
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 481
# predictions:
# label:  | data: -0.931616623563414 | operation: tanh | grad: 0.0
# label:  | data: 0.9567984818332674 | operation: tanh | grad: 0.0
# label:  | data: 0.999901933658927 | operation: tanh | grad: 0.0
# label:  | data: -0.9930521040385892 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016477350550190466
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 482
# predictions:
# label:  | data: -0.9316927222602881 | operation: tanh | grad: 0.0
# label:  | data: 0.9568460177685933 | operation: tanh | grad: 0.0
# label:  | data: 0.9999020909853829 | operation: tanh | grad: 0.0
# label:  | data: -0.9930588810182803 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016440847733830586
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 483
# predictions:
# label:  | data: -0.931768573095409 | operation: tanh | grad: 0.0
# label:  | data: 0.9568933998184828 | operation: tanh | grad: 0.0
# label:  | data: 0.999902247720485 | operation: tanh | grad: 0.0
# label:  | data: -0.993065636621036 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016404503869063504
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 484
# predictions:
# label:  | data: -0.9318441773995684 | operation: tanh | grad: 0.0
# label:  | data: 0.9569406288051818 | operation: tanh | grad: 0.0
# label:  | data: 0.9999024038677132 | operation: tanh | grad: 0.0
# label:  | data: -0.9930723709601487 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016368317927883682
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 485
# predictions:
# label:  | data: -0.9319195364936285 | operation: tanh | grad: 0.0
# label:  | data: 0.9569877055448255 | operation: tanh | grad: 0.0
# label:  | data: 0.9999025594305214 | operation: tanh | grad: 0.0
# label:  | data: -0.99307908414807 | operation: tanh | grad: 0.0
# epoch_loss: 0.001633228889108775
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 486
# predictions:
# label:  | data: -0.9319946516886154 | operation: tanh | grad: 0.0
# label:  | data: 0.9570346308474972 | operation: tanh | grad: 0.0
# label:  | data: 0.9999027144123342 | operation: tanh | grad: 0.0
# label:  | data: -0.9930857762964185 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016296415748180797
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 487
# predictions:
# label:  | data: -0.9320695242858119 | operation: tanh | grad: 0.0
# label:  | data: 0.9570814055172859 | operation: tanh | grad: 0.0
# label:  | data: 0.9999028688165505 | operation: tanh | grad: 0.0
# label:  | data: -0.9930924475159874 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016260697497284349
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 488
# predictions:
# label:  | data: -0.9321441555768524 | operation: tanh | grad: 0.0
# label:  | data: 0.9571280303523416 | operation: tanh | grad: 0.0
# label:  | data: 0.9999030226465405 | operation: tanh | grad: 0.0
# label:  | data: -0.9930990979167537 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016225133145044486
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 489
# predictions:
# label:  | data: -0.9322185468438114 | operation: tanh | grad: 0.0
# label:  | data: 0.9571745061449336 | operation: tanh | grad: 0.0
# label:  | data: 0.9999031759056495 | operation: tanh | grad: 0.0
# label:  | data: -0.9931057276078846 | operation: tanh | grad: 0.0
# epoch_loss: 0.001618972170654211
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 490
# predictions:
# label:  | data: -0.9322926993592965 | operation: tanh | grad: 0.0
# label:  | data: 0.9572208336815036 | operation: tanh | grad: 0.0
# label:  | data: 0.9999033285971949 | operation: tanh | grad: 0.0
# label:  | data: -0.9931123366977455 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016154462205203836
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 491
# predictions:
# label:  | data: -0.932366614386536 | operation: tanh | grad: 0.0
# label:  | data: 0.9572670137427227 | operation: tanh | grad: 0.0
# label:  | data: 0.9999034807244687 | operation: tanh | grad: 0.0
# label:  | data: -0.9931189252939072 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016119353672713866
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 492
# predictions:
# label:  | data: -0.9324402931794692 | operation: tanh | grad: 0.0
# label:  | data: 0.9573130471035441 | operation: tanh | grad: 0.0
# label:  | data: 0.9999036322907362 | operation: tanh | grad: 0.0
# label:  | data: -0.993125493503155 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016084395148927174
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 493
# predictions:
# label:  | data: -0.9325137369828317 | operation: tanh | grad: 0.0
# label:  | data: 0.9573589345332567 | operation: tanh | grad: 0.0
# label:  | data: 0.9999037832992382 | operation: tanh | grad: 0.0
# label:  | data: -0.9931320414314938 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016049585681784326
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 494
# predictions:
# label:  | data: -0.9325869470322427 | operation: tanh | grad: 0.0
# label:  | data: 0.957404676795539 | operation: tanh | grad: 0.0
# label:  | data: 0.9999039337531892 | operation: tanh | grad: 0.0
# label:  | data: -0.9931385691841572 | operation: tanh | grad: 0.0
# epoch_loss: 0.0016014924327226317
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 495
# predictions:
# label:  | data: -0.9326599245542904 | operation: tanh | grad: 0.0
# label:  | data: 0.9574502746485107 | operation: tanh | grad: 0.0
# label:  | data: 0.9999040836557785 | operation: tanh | grad: 0.0
# label:  | data: -0.9931450768656129 | operation: tanh | grad: 0.0
# epoch_loss: 0.0015980410149111191
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 496
# predictions:
# label:  | data: -0.9327326707666165 | operation: tanh | grad: 0.0
# label:  | data: 0.9574957288447848 | operation: tanh | grad: 0.0
# label:  | data: 0.9999042330101713 | operation: tanh | grad: 0.0
# label:  | data: -0.9931515645795728 | operation: tanh | grad: 0.0
# epoch_loss: 0.001594604221913143
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 497
# predictions:
# label:  | data: -0.9328051868779995 | operation: tanh | grad: 0.0
# label:  | data: 0.9575410401315188 | operation: tanh | grad: 0.0
# label:  | data: 0.9999043818195071 | operation: tanh | grad: 0.0
# label:  | data: -0.9931580324289966 | operation: tanh | grad: 0.0
# epoch_loss: 0.0015911819616732435
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 498
# predictions:
# label:  | data: -0.9328774740884375 | operation: tanh | grad: 0.0
# label:  | data: 0.9575862092504642 | operation: tanh | grad: 0.0
# label:  | data: 0.9999045300869017 | operation: tanh | grad: 0.0
# label:  | data: -0.993164480516101 | operation: tanh | grad: 0.0
# epoch_loss: 0.0015877741429032152
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 499
# predictions:
# label:  | data: -0.9329495335892284 | operation: tanh | grad: 0.0
# label:  | data: 0.9576312369380182 | operation: tanh | grad: 0.0
# label:  | data: 0.9999046778154463 | operation: tanh | grad: 0.0
# label:  | data: -0.9931709089423659 | operation: tanh | grad: 0.0
# epoch_loss: 0.0015843806750741726
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Now, let's try different functions of varying complexity and see how the same Neural Network architecture performs.

# %% [markdown]
# ### Simple Function
#
# $$f(x, y, z) = x + y - z$$

# %%
neural_network2 = MultiLayerPerceptron(num_inputs=3, num_neurons_per_layer=[4, 4, 1])

# %%
# data_point1 = [1, 1, 1]  => x + y - z = 1 + 1 - 1  => target = 1
# data_point2 = [0, 2, 4]  => x + y - z = 0 + 2 - 4  => target = -2
# data_point3 = [-2, 4, 2] => x + y - z = -2 + 4 - 2 => target = 0
# data_point4 = [3, 1, 5]  => x + y - z = 3 + 1 - 5  => target = -1
inputs2 = [[1, 1, 1], [0, 2, 4], [-2, 4, 2], [3, 1, 5]]
targets2 = [1, -2, 0, -1]

# %%
initial_predictions2 = [neural_network2(input)[0] for input in inputs2]
initial_predictions2
# Out:
# [label:  | data: 0.9678275656684154 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9721701909349519 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9715426531056797 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9722274839234522 | operation: tanh | grad: 0.0]

# %%
# Note the the loss is not decreasing beyond 0.25 in this case. The neural network is able to learn the function
# to some extent but it is not able to learn the function completely. There could be multiple reasons for this:
#
# 1) This function is not as simple as the previous function. The neural network might need more neurons or more
#    layers to learn this function.
# 2) The data is not enough. The neural network might need more data to learn this particular function.
train_model(model=neural_network2, inputs=inputs2, targets=targets2, num_epochs=500, learning_rate=0.1)
# Out:
# epoch: 0
# predictions:
# label:  | data: 0.9678275656684154 | operation: tanh | grad: 0.0
# label:  | data: 0.9721701909349519 | operation: tanh | grad: 0.0
# label:  | data: 0.9715426531056797 | operation: tanh | grad: 0.0
# label:  | data: 0.9722274839234522 | operation: tanh | grad: 0.0
# epoch_loss: 3.417101771139946
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 1
# predictions:
# label:  | data: 0.962736033935928 | operation: tanh | grad: 0.0
# label:  | data: 0.967703351465742 | operation: tanh | grad: 0.0
# label:  | data: 0.9669840552610888 | operation: tanh | grad: 0.0
# label:  | data: 0.9677684418399695 | operation: tanh | grad: 0.0
# epoch_loss: 3.403955647324576
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 2
# predictions:
# label:  | data: 0.95589358693808 | operation: tanh | grad: 0.0
# label:  | data: 0.9616825222575651 | operation: tanh | grad: 0.0
# label:  | data: 0.9608423048357109 | operation: tanh | grad: 0.0
# label:  | data: 0.9617577356435714 | operation: tanh | grad: 0.0
# epoch_loss: 3.3863050216096284
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 3
# predictions:
# label:  | data: 0.946287727080667 | operation: tanh | grad: 0.0
# label:  | data: 0.9531985939001233 | operation: tanh | grad: 0.0
# label:  | data: 0.9521928894473486 | operation: tanh | grad: 0.0
# label:  | data: 0.9532873998407116 | operation: tanh | grad: 0.0
# epoch_loss: 3.3615674770916018
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 4
# predictions:
# label:  | data: 0.9320091854483473 | operation: tanh | grad: 0.0
# label:  | data: 0.9405266839281753 | operation: tanh | grad: 0.0
# label:  | data: 0.9392833906935908 | operation: tanh | grad: 0.0
# label:  | data: 0.9406345151555523 | operation: tanh | grad: 0.0
# epoch_loss: 3.3249088848007258
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 5
# predictions:
# label:  | data: 0.9090850546346451 | operation: tanh | grad: 0.0
# label:  | data: 0.9200472929472409 | operation: tanh | grad: 0.0
# label:  | data: 0.9184413774672525 | operation: tanh | grad: 0.0
# label:  | data: 0.9201831277954833 | operation: tanh | grad: 0.0
# epoch_loss: 3.2663948821134214
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 6
# predictions:
# label:  | data: 0.8681328043941854 | operation: tanh | grad: 0.0
# label:  | data: 0.88310635669881 | operation: tanh | grad: 0.0
# label:  | data: 0.880903271214079 | operation: tanh | grad: 0.0
# label:  | data: 0.8832857287977977 | operation: tanh | grad: 0.0
# epoch_loss: 3.163111732710786
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 7
# predictions:
# label:  | data: 0.7832523806126868 | operation: tanh | grad: 0.0
# label:  | data: 0.8053279095549029 | operation: tanh | grad: 0.0
# label:  | data: 0.8020628738636459 | operation: tanh | grad: 0.0
# label:  | data: 0.8055765888129234 | operation: tanh | grad: 0.0
# epoch_loss: 2.9550639705843675
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 8
# predictions:
# label:  | data: 0.5727947806028713 | operation: tanh | grad: 0.0
# label:  | data: 0.6068654689464258 | operation: tanh | grad: 0.0
# label:  | data: 0.6018016949887527 | operation: tanh | grad: 0.0
# label:  | data: 0.6071976168104242 | operation: tanh | grad: 0.0
# epoch_loss: 2.480875333059465
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 9
# predictions:
# label:  | data: 0.057688409316671505 | operation: tanh | grad: 0.0
# label:  | data: 0.09590979034321101 | operation: tanh | grad: 0.0
# label:  | data: 0.09030567518795772 | operation: tanh | grad: 0.0
# label:  | data: 0.09611722701922541 | operation: tanh | grad: 0.0
# epoch_loss: 1.6226042683830344
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 10
# predictions:
# label:  | data: -0.4020387366755021 | operation: tanh | grad: 0.0
# label:  | data: -0.3811449377075107 | operation: tanh | grad: 0.0
# label:  | data: -0.3839954463810694 | operation: tanh | grad: 0.0
# label:  | data: -0.3812166051713608 | operation: tanh | grad: 0.0
# epoch_loss: 1.2791874311014273
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 11
# predictions:
# label:  | data: -0.4733735963828435 | operation: tanh | grad: 0.0
# label:  | data: -0.4568217190373738 | operation: tanh | grad: 0.0
# label:  | data: -0.4590338444900227 | operation: tanh | grad: 0.0
# label:  | data: -0.4569381934598378 | operation: tanh | grad: 0.0
# epoch_loss: 1.2644642893657092
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 12
# predictions:
# label:  | data: -0.4997105410014421 | operation: tanh | grad: 0.0
# label:  | data: -0.48522878713510154 | operation: tanh | grad: 0.0
# label:  | data: -0.4871554876990565 | operation: tanh | grad: 0.0
# label:  | data: -0.48536439609889936 | operation: tanh | grad: 0.0
# epoch_loss: 1.2614584520282472
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 13
# predictions:
# label:  | data: -0.5117458951146945 | operation: tanh | grad: 0.0
# label:  | data: -0.49857708846096993 | operation: tanh | grad: 0.0
# label:  | data: -0.5003340574412705 | operation: tanh | grad: 0.0
# label:  | data: -0.49872436070005627 | operation: tanh | grad: 0.0
# epoch_loss: 1.2603144615704198
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 14
# predictions:
# label:  | data: -0.5175623871860194 | operation: tanh | grad: 0.0
# label:  | data: -0.5053657840295576 | operation: tanh | grad: 0.0
# label:  | data: -0.5070044209666011 | operation: tanh | grad: 0.0
# label:  | data: -0.5055215895672636 | operation: tanh | grad: 0.0
# epoch_loss: 1.2596223549537684
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 15
# predictions:
# label:  | data: -0.5203154076445524 | operation: tanh | grad: 0.0
# label:  | data: -0.5089143521958824 | operation: tanh | grad: 0.0
# label:  | data: -0.5104608809937938 | operation: tanh | grad: 0.0
# label:  | data: -0.5090771241307498 | operation: tanh | grad: 0.0
# epoch_loss: 1.2590677322213852
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 16
# predictions:
# label:  | data: -0.5214686795888408 | operation: tanh | grad: 0.0
# label:  | data: -0.5107627100795423 | operation: tanh | grad: 0.0
# label:  | data: -0.5122316894173944 | operation: tanh | grad: 0.0
# label:  | data: -0.5109315616677944 | operation: tanh | grad: 0.0
# epoch_loss: 1.2585659724188851
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 17
# predictions:
# label:  | data: -0.5217641255038973 | operation: tanh | grad: 0.0
# label:  | data: -0.5116915515542441 | operation: tanh | grad: 0.0
# label:  | data: -0.513091608874989 | operation: tanh | grad: 0.0
# label:  | data: -0.5118659240816099 | operation: tanh | grad: 0.0
# epoch_loss: 1.2580914916390697
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 18
# predictions:
# label:  | data: -0.5215960508079829 | operation: tanh | grad: 0.0
# label:  | data: -0.5121161203276955 | operation: tanh | grad: 0.0
# label:  | data: -0.5134526860567084 | operation: tanh | grad: 0.0
# label:  | data: -0.5122956228151065 | operation: tanh | grad: 0.0
# epoch_loss: 1.257635550391828
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 19
# predictions:
# label:  | data: -0.5211793069994162 | operation: tanh | grad: 0.0
# label:  | data: -0.5122631247469318 | operation: tanh | grad: 0.0
# label:  | data: -0.513539828937159 | operation: tanh | grad: 0.0
# label:  | data: -0.5124474547891559 | operation: tanh | grad: 0.0
# epoch_loss: 1.2571945335693415
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 20
# predictions:
# label:  | data: -0.5206323561744257 | operation: tanh | grad: 0.0
# label:  | data: -0.512258065770049 | operation: tanh | grad: 0.0
# label:  | data: -0.5134774820669431 | operation: tanh | grad: 0.0
# label:  | data: -0.5124469683005046 | operation: tanh | grad: 0.0
# epoch_loss: 1.2567664772050096
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 21
# predictions:
# label:  | data: -0.520020723675243 | operation: tanh | grad: 0.0
# label:  | data: -0.5121708798412766 | operation: tanh | grad: 0.0
# label:  | data: -0.5133349327271846 | operation: tanh | grad: 0.0
# label:  | data: -0.5123641247743358 | operation: tanh | grad: 0.0
# epoch_loss: 1.2563499977899033
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 22
# predictions:
# label:  | data: -0.5193805116464015 | operation: tanh | grad: 0.0
# label:  | data: -0.5120406149745291 | operation: tanh | grad: 0.0
# label:  | data: -0.5131508072304592 | operation: tanh | grad: 0.0
# label:  | data: -0.5122379846109815 | operation: tanh | grad: 0.0
# epoch_loss: 1.2559439513184718
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 23
# predictions:
# label:  | data: -0.5187313724306098 | operation: tanh | grad: 0.0
# label:  | data: -0.5118890342459306 | operation: tanh | grad: 0.0
# label:  | data: -0.512946576305446 | operation: tanh | grad: 0.0
# label:  | data: -0.5120903158431793 | operation: tanh | grad: 0.0
# epoch_loss: 1.25554731950999
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 24
# predictions:
# label:  | data: -0.5180837441212465 | operation: tanh | grad: 0.0
# label:  | data: -0.5117281980332048 | operation: tanh | grad: 0.0
# label:  | data: -0.5127340829730568 | operation: tanh | grad: 0.0
# label:  | data: -0.5119331791411007 | operation: tanh | grad: 0.0
# epoch_loss: 1.255159168040052
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 25
# predictions:
# label:  | data: -0.517442908857809 | operation: tanh | grad: 0.0
# label:  | data: -0.5115647156082826 | operation: tanh | grad: 0.0
# label:  | data: -0.5125197636217143 | operation: tanh | grad: 0.0
# label:  | data: -0.5117731808917049 | operation: tanh | grad: 0.0
# epoch_loss: 1.2547786281161408
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 26
# predictions:
# label:  | data: -0.5168112747988332 | operation: tanh | grad: 0.0
# label:  | data: -0.5114021364936419 | operation: tanh | grad: 0.0
# label:  | data: -0.5123070219908693 | operation: tanh | grad: 0.0
# label:  | data: -0.5116138653495401 | operation: tanh | grad: 0.0
# epoch_loss: 1.2544048859731314
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 27
# predictions:
# label:  | data: -0.5161896598248109 | operation: tanh | grad: 0.0
# label:  | data: -0.5112422972853427 | operation: tanh | grad: 0.0
# label:  | data: -0.5120975659226396 | operation: tanh | grad: 0.0
# label:  | data: -0.5114570618742326 | operation: tanh | grad: 0.0
# epoch_loss: 1.2540371753420874
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 28
# predictions:
# label:  | data: -0.515578012757488 | operation: tanh | grad: 0.0
# label:  | data: -0.511086080312253 | operation: tanh | grad: 0.0
# label:  | data: -0.5118921600302865 | operation: tanh | grad: 0.0
# label:  | data: -0.511303643791951 | operation: tanh | grad: 0.0
# epoch_loss: 1.2536747712663412
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 29
# predictions:
# label:  | data: -0.5149758173062585 | operation: tanh | grad: 0.0
# label:  | data: -0.5109338406616103 | operation: tanh | grad: 0.0
# label:  | data: -0.5116910490268974 | operation: tanh | grad: 0.0
# label:  | data: -0.5111539555015644 | operation: tanh | grad: 0.0
# epoch_loss: 1.2533169846963905
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 30
# predictions:
# label:  | data: -0.5143823170450412 | operation: tanh | grad: 0.0
# label:  | data: -0.5107856461289199 | operation: tanh | grad: 0.0
# label:  | data: -0.511494195275857 | operation: tanh | grad: 0.0
# label:  | data: -0.5110080524323906 | operation: tanh | grad: 0.0
# epoch_loss: 1.2529631576353064
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 31
# predictions:
# label:  | data: -0.5137966395071907 | operation: tanh | grad: 0.0
# label:  | data: -0.5106414116525324 | operation: tanh | grad: 0.0
# label:  | data: -0.5113014115647739 | operation: tanh | grad: 0.0
# label:  | data: -0.5108658354401795 | operation: tanh | grad: 0.0
# epoch_loss: 1.2526126587188473
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 32
# predictions:
# label:  | data: -0.5132178634977369 | operation: tanh | grad: 0.0
# label:  | data: -0.5105009742722687 | operation: tanh | grad: 0.0
# label:  | data: -0.5111124348267844 | operation: tanh | grad: 0.0
# label:  | data: -0.5107271256946265 | operation: tanh | grad: 0.0
# epoch_loss: 1.2522648791545308
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 33
# predictions:
# label:  | data: -0.5126450545189863 | operation: tanh | grad: 0.0
# label:  | data: -0.5103641346015833 | operation: tanh | grad: 0.0
# label:  | data: -0.5109269666187346 | operation: tanh | grad: 0.0
# label:  | data: -0.5105917060550572 | operation: tanh | grad: 0.0
# epoch_loss: 1.2519192289605896
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 34
# predictions:
# label:  | data: -0.5120772823520209 | operation: tanh | grad: 0.0
# label:  | data: -0.5102306794804626 | operation: tanh | grad: 0.0
# label:  | data: -0.5107446949189838 | operation: tanh | grad: 0.0
# label:  | data: -0.5104593436048175 | operation: tanh | grad: 0.0
# epoch_loss: 1.2515751334545075
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 35
# predictions:
# label:  | data: -0.5115136287026617 | operation: tanh | grad: 0.0
# label:  | data: -0.5101003940819764 | operation: tanh | grad: 0.0
# label:  | data: -0.5105653054554934 | operation: tanh | grad: 0.0
# label:  | data: -0.5103298016184643 | operation: tanh | grad: 0.0
# epoch_loss: 1.2512320299466109
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 36
# predictions:
# label:  | data: -0.5109531893548532 | operation: tanh | grad: 0.0
# label:  | data: -0.5099730681347593 | operation: tanh | grad: 0.0
# label:  | data: -0.5103884871877434 | operation: tanh | grad: 0.0
# label:  | data: -0.5102028456239053 | operation: tanh | grad: 0.0
# epoch_loss: 1.2508893645985146
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 37
# predictions:
# label:  | data: -0.5103950733173865 | operation: tanh | grad: 0.0
# label:  | data: -0.5098484988855168 | operation: tanh | grad: 0.0
# label:  | data: -0.5102139345409267 | operation: tanh | grad: 0.0
# label:  | data: -0.5100782461826293 | operation: tanh | grad: 0.0
# epoch_loss: 1.2505465894096004
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 38
# predictions:
# label:  | data: -0.509838400345507 | operation: tanh | grad: 0.0
# label:  | data: -0.5097264922757099 | operation: tanh | grad: 0.0
# label:  | data: -0.510041347848076 | operation: tanh | grad: 0.0
# label:  | data: -0.5099557798606213 | operation: tanh | grad: 0.0
# epoch_loss: 1.2502031592973581
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 39
# predictions:
# label:  | data: -0.5092822975962672 | operation: tanh | grad: 0.0
# label:  | data: -0.5096068631581887 | operation: tanh | grad: 0.0
# label:  | data: -0.5098704328111923 | operation: tanh | grad: 0.0
# label:  | data: -0.5098352292136922 | operation: tanh | grad: 0.0
# epoch_loss: 1.249858529239427
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 40
# predictions:
# label:  | data: -0.5087258958257301 | operation: tanh | grad: 0.0
# label:  | data: -0.5094894350143572 | operation: tanh | grad: 0.0
# label:  | data: -0.509700899429057 | operation: tanh | grad: 0.0
# label:  | data: -0.5097163822453294 | operation: tanh | grad: 0.0
# epoch_loss: 1.2495121514465923
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 41
# predictions:
# label:  | data: -0.5081683253387116 | operation: tanh | grad: 0.0
# label:  | data: -0.509374039427063 | operation: tanh | grad: 0.0
# label:  | data: -0.5095324606346312 | operation: tanh | grad: 0.0
# label:  | data: -0.5095990315893386 | operation: tanh | grad: 0.0
# epoch_loss: 1.2491634725368652
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 42
# predictions:
# label:  | data: -0.5076087117906433 | operation: tanh | grad: 0.0
# label:  | data: -0.5092605154491423 | operation: tanh | grad: 0.0
# label:  | data: -0.5093648307695027 | operation: tanh | grad: 0.0
# label:  | data: -0.5094829735538193 | operation: tanh | grad: 0.0
# epoch_loss: 1.2488119306811116
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 43
# predictions:
# label:  | data: -0.5070461718784777 | operation: tanh | grad: 0.0
# label:  | data: -0.5091487089431233 | operation: tanh | grad: 0.0
# label:  | data: -0.5091977239576875 | operation: tanh | grad: 0.0
# label:  | data: -0.5093680070980816 | operation: tanh | grad: 0.0
# epoch_loss: 1.2484569526905318
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 44
# predictions:
# label:  | data: -0.5064798089219282 | operation: tanh | grad: 0.0
# label:  | data: -0.5090384719317518 | operation: tanh | grad: 0.0
# label:  | data: -0.509030852404044 | operation: tanh | grad: 0.0
# label:  | data: -0.5092539327776936 | operation: tanh | grad: 0.0
# epoch_loss: 1.2480979510156007
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 45
# predictions:
# label:  | data: -0.5059087083156651 | operation: tanh | grad: 0.0
# label:  | data: -0.508929661979293 | operation: tanh | grad: 0.0
# label:  | data: -0.5088639246212511 | operation: tanh | grad: 0.0
# label:  | data: -0.5091405516724998 | operation: tanh | grad: 0.0
# epoch_loss: 1.2477343206248652
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 46
# predictions:
# label:  | data: -0.5053319328205187 | operation: tanh | grad: 0.0
# label:  | data: -0.5088221416128978 | operation: tanh | grad: 0.0
# label:  | data: -0.5086966435765657 | operation: tanh | grad: 0.0
# label:  | data: -0.5090276643010375 | operation: tanh | grad: 0.0
# epoch_loss: 1.2473654357302153
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 47
# predictions:
# label:  | data: -0.5047485176533949 | operation: tanh | grad: 0.0
# label:  | data: -0.508715777787732 | operation: tanh | grad: 0.0
# label:  | data: -0.5085287047414833 | operation: tanh | grad: 0.0
# label:  | data: -0.508915069518354 | operation: tanh | grad: 0.0
# epoch_loss: 1.2469906463228884
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 48
# predictions:
# label:  | data: -0.5041574653292602 | operation: tanh | grad: 0.0
# label:  | data: -0.5086104413968622 | operation: tanh | grad: 0.0
# label:  | data: -0.5083597940216389 | operation: tanh | grad: 0.0
# label:  | data: -0.5088025633905389 | operation: tanh | grad: 0.0
# epoch_loss: 1.246609274481409
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 49
# predictions:
# label:  | data: -0.5035577402029322 | operation: tanh | grad: 0.0
# label:  | data: -0.5085060068257737 | operation: tanh | grad: 0.0
# label:  | data: -0.5081895855394817 | operation: tanh | grad: 0.0
# label:  | data: -0.5086899380370584 | operation: tanh | grad: 0.0
# epoch_loss: 1.2462206104089415
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 50
# predictions:
# label:  | data: -0.5029482626527024 | operation: tanh | grad: 0.0
# label:  | data: -0.5084023515512224 | operation: tanh | grad: 0.0
# label:  | data: -0.5080177392376214 | operation: tanh | grad: 0.0
# label:  | data: -0.5085769804305075 | operation: tanh | grad: 0.0
# epoch_loss: 1.2458239081529003
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 51
# predictions:
# label:  | data: -0.5023279028415738 | operation: tanh | grad: 0.0
# label:  | data: -0.5082993557845017 | operation: tanh | grad: 0.0
# label:  | data: -0.5078438982657717 | operation: tanh | grad: 0.0
# label:  | data: -0.5084634711422695 | operation: tanh | grad: 0.0
# epoch_loss: 1.245418380954144
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 52
# predictions:
# label:  | data: -0.5016954739847163 | operation: tanh | grad: 0.0
# label:  | data: -0.508196902159935 | operation: tanh | grad: 0.0
# label:  | data: -0.5076676861084828 | operation: tanh | grad: 0.0
# label:  | data: -0.508349183021574 | operation: tanh | grad: 0.0
# epoch_loss: 1.2450031961664227
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 53
# predictions:
# label:  | data: -0.5010497250433614 | operation: tanh | grad: 0.0
# label:  | data: -0.5080948754704155 | operation: tanh | grad: 0.0
# label:  | data: -0.5074887034040806 | operation: tanh | grad: 0.0
# label:  | data: -0.5082338797944198 | operation: tanh | grad: 0.0
# epoch_loss: 1.2445774696787975
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 54
# predictions:
# label:  | data: -0.5003893327554931 | operation: tanh | grad: 0.0
# label:  | data: -0.507993162453058 | operation: tanh | grad: 0.0
# label:  | data: -0.5073065243970513 | operation: tanh | grad: 0.0
# label:  | data: -0.5081173145677255 | operation: tanh | grad: 0.0
# epoch_loss: 1.2441402597642957
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 55
# predictions:
# label:  | data: -0.49971289290204673 | operation: tanh | grad: 0.0
# label:  | data: -0.5078916516295338 | operation: tanh | grad: 0.0
# label:  | data: -0.5071206929561911 | operation: tanh | grad: 0.0
# label:  | data: -0.5079992282228073 | operation: tanh | grad: 0.0
# epoch_loss: 1.243690560266797
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 56
# predictions:
# label:  | data: -0.49901891069358095 | operation: tanh | grad: 0.0
# label:  | data: -0.507790233207453 | operation: tanh | grad: 0.0
# label:  | data: -0.5069307180787426 | operation: tanh | grad: 0.0
# label:  | data: -0.5078793476808698 | operation: tanh | grad: 0.0
# epoch_loss: 1.2432272930247186
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 57
# predictions:
# label:  | data: -0.49830579014615267 | operation: tanh | grad: 0.0
# label:  | data: -0.507688799051341 | operation: tanh | grad: 0.0
# label:  | data: -0.5067360687859505 | operation: tanh | grad: 0.0
# label:  | data: -0.5077573840215704 | operation: tanh | grad: 0.0
# epoch_loss: 1.2427492994140608
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 58
# predictions:
# label:  | data: -0.49757182229593044 | operation: tanh | grad: 0.0
# label:  | data: -0.5075872427343507 | operation: tanh | grad: 0.0
# label:  | data: -0.5065361682973178 | operation: tanh | grad: 0.0
# label:  | data: -0.5076330304339047 | operation: tanh | grad: 0.0
# epoch_loss: 1.24225533087426
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 59
# predictions:
# label:  | data: -0.4968151720793861 | operation: tanh | grad: 0.0
# label:  | data: -0.5074854596850769 | operation: tanh | grad: 0.0
# label:  | data: -0.5063303873485193 | operation: tanh | grad: 0.0
# label:  | data: -0.5075059599766092 | operation: tanh | grad: 0.0
# epoch_loss: 1.2417440382573928
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 60
# predictions:
# label:  | data: -0.4960338636790244 | operation: tanh | grad: 0.0
# label:  | data: -0.5073833474477611 | operation: tanh | grad: 0.0
# label:  | data: -0.5061180364903365 | operation: tanh | grad: 0.0
# label:  | data: -0.5073758231230516 | operation: tanh | grad: 0.0
# epoch_loss: 1.2412139598137915
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 61
# predictions:
# label:  | data: -0.49522576410271996 | operation: tanh | grad: 0.0
# label:  | data: -0.5072808060790476 | operation: tanh | grad: 0.0
# label:  | data: -0.5058983571717988 | operation: tanh | grad: 0.0
# label:  | data: -0.5072422450631286 | operation: tanh | grad: 0.0
# epoch_loss: 1.2406635075940327
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 62
# predictions:
# label:  | data: -0.49438856472682763 | operation: tanh | grad: 0.0
# label:  | data: -0.5071777387105142 | operation: tanh | grad: 0.0
# label:  | data: -0.505670511368135 | operation: tanh | grad: 0.0
# label:  | data: -0.5071048227320888 | operation: tanh | grad: 0.0
# epoch_loss: 1.2400909520072596
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 63
# predictions:
# label:  | data: -0.4935197604880861 | operation: tanh | grad: 0.0
# label:  | data: -0.5070740523137995 | operation: tanh | grad: 0.0
# label:  | data: -0.5054335694609003 | operation: tanh | grad: 0.0
# label:  | data: -0.5069631215335114 | operation: tanh | grad: 0.0
# epoch_loss: 1.2394944042272737
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 64
# predictions:
# label:  | data: -0.492616626355409 | operation: tanh | grad: 0.0
# label:  | data: -0.5069696587147011 | operation: tanh | grad: 0.0
# label:  | data: -0.505186496010736 | operation: tanh | grad: 0.0
# label:  | data: -0.5068166717209512 | operation: tanh | grad: 0.0
# epoch_loss: 1.2388717960787758
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 65
# predictions:
# label:  | data: -0.4916761906481111 | operation: tanh | grad: 0.0
# label:  | data: -0.5068644759147023 | operation: tanh | grad: 0.0
# label:  | data: -0.5049281329786894 | operation: tanh | grad: 0.0
# label:  | data: -0.5066649644002253 | operation: tanh | grad: 0.0
# epoch_loss: 1.2382208569638782
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 66
# predictions:
# label:  | data: -0.49069520468958816 | operation: tanh | grad: 0.0
# label:  | data: -0.5067584297937522 | operation: tanh | grad: 0.0
# label:  | data: -0.504657179844688 | operation: tanh | grad: 0.0
# label:  | data: -0.5065074471121728 | operation: tanh | grad: 0.0
# epoch_loss: 1.237539087300273
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 67
# predictions:
# label:  | data: -0.489670108192127 | operation: tanh | grad: 0.0
# label:  | data: -0.5066514562877369 | operation: tanh | grad: 0.0
# label:  | data: -0.5043721699346296 | operation: tanh | grad: 0.0
# label:  | data: -0.5063435189543416 | operation: tanh | grad: 0.0
# epoch_loss: 1.2368237278329075
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 68
# predictions:
# label:  | data: -0.48859698965574333 | operation: tanh | grad: 0.0
# label:  | data: -0.5065435041592523 | operation: tanh | grad: 0.0
# label:  | data: -0.5040714420913666 | operation: tanh | grad: 0.0
# label:  | data: -0.5061725252000115 | operation: tanh | grad: 0.0
# epoch_loss: 1.2360717240451173
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 69
# predictions:
# label:  | data: -0.4874715409272752 | operation: tanh | grad: 0.0
# label:  | data: -0.5064345385127683 | operation: tanh | grad: 0.0
# label:  | data: -0.5037531065969946 | operation: tanh | grad: 0.0
# label:  | data: -0.5059937513750501 | operation: tanh | grad: 0.0
# epoch_loss: 1.2352796847256873
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 70
# predictions:
# label:  | data: -0.48628900489978133 | operation: tanh | grad: 0.0
# label:  | data: -0.5063245452473879 | operation: tanh | grad: 0.0
# label:  | data: -0.5034150039572571 | operation: tanh | grad: 0.0
# label:  | data: -0.505806416758536 | operation: tanh | grad: 0.0
# epoch_loss: 1.234443833535682
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 71
# predictions:
# label:  | data: -0.48504411512955203 | operation: tanh | grad: 0.0
# label:  | data: -0.5062135366953371 | operation: tanh | grad: 0.0
# label:  | data: -0.503054654770066 | operation: tanh | grad: 0.0
# label:  | data: -0.5056096672836242 | operation: tanh | grad: 0.0
# epoch_loss: 1.2335599521506013
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 72
# predictions:
# label:  | data: -0.48373102589983763 | operation: tanh | grad: 0.0
# label:  | data: -0.5061015587663723 | operation: tanh | grad: 0.0
# label:  | data: -0.5026691983867398 | operation: tanh | grad: 0.0
# label:  | data: -0.5054025678333853 | operation: tanh | grad: 0.0
# epoch_loss: 1.2326233132126556
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 73
# predictions:
# label:  | data: -0.4823432309555087 | operation: tanh | grad: 0.0
# label:  | data: -0.5059887000134389 | operation: tanh | grad: 0.0
# label:  | data: -0.5022553173914502 | operation: tanh | grad: 0.0
# label:  | data: -0.5051840939561205 | operation: tanh | grad: 0.0
# epoch_loss: 1.2316286008922905
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 74
# predictions:
# label:  | data: -0.48087346875702786 | operation: tanh | grad: 0.0
# label:  | data: -0.5058751031613455 | operation: tanh | grad: 0.0
# label:  | data: -0.5018091440080701 | operation: tanh | grad: 0.0
# label:  | data: -0.504953123071574 | operation: tanh | grad: 0.0
# epoch_loss: 1.2305698162970728
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 75
# predictions:
# label:  | data: -0.47931361163726677 | operation: tanh | grad: 0.0
# label:  | data: -0.5057609798094773 | operation: tanh | grad: 0.0
# label:  | data: -0.5013261433041761 | operation: tanh | grad: 0.0
# label:  | data: -0.5047084253118164 | operation: tanh | grad: 0.0
# epoch_loss: 1.2294401642381418
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 76
# predictions:
# label:  | data: -0.47765453566790883 | operation: tanh | grad: 0.0
# label:  | data: -0.5056466292478797 | operation: tanh | grad: 0.0
# label:  | data: -0.5008009663704538 | operation: tanh | grad: 0.0
# label:  | data: -0.5044486542507217 | operation: tanh | grad: 0.0
# epoch_loss: 1.2282319169124174
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 77
# predictions:
# label:  | data: -0.4758859673242878 | operation: tanh | grad: 0.0
# label:  | data: -0.5055324626365477 | operation: tanh | grad: 0.0
# label:  | data: -0.5002272643238489 | operation: tanh | grad: 0.0
# label:  | data: -0.504172337942307 | operation: tanh | grad: 0.0
# epoch_loss: 1.2269362488031124
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 78
# predictions:
# label:  | data: -0.4739963021416923 | operation: tanh | grad: 0.0
# label:  | data: -0.5054190342238082 | operation: tanh | grad: 0.0
# label:  | data: -0.4995974507421623 | operation: tanh | grad: 0.0
# label:  | data: -0.5038778709384839 | operation: tanh | grad: 0.0
# epoch_loss: 1.2255430354301189
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 79
# predictions:
# label:  | data: -0.47197238943594694 | operation: tanh | grad: 0.0
# label:  | data: -0.5053070818698624 | operation: tanh | grad: 0.0
# label:  | data: -0.49890239558439387 | operation: tanh | grad: 0.0
# label:  | data: -0.5035635083329923 | operation: tanh | grad: 0.0
# epoch_loss: 1.2240406063371627
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 80
# predictions:
# label:  | data: -0.4697992757586953 | operation: tanh | grad: 0.0
# label:  | data: -0.5051975799675761 | operation: tanh | grad: 0.0
# label:  | data: -0.4981310271850215 | operation: tanh | grad: 0.0
# label:  | data: -0.5032273634447553 | operation: tanh | grad: 0.0
# epoch_loss: 1.2224154396575075
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 81
# predictions:
# label:  | data: -0.46745989800246657 | operation: tanh | grad: 0.0
# label:  | data: -0.5050918090216112 | operation: tanh | grad: 0.0
# label:  | data: -0.4972698096263197 | operation: tanh | grad: 0.0
# label:  | data: -0.5028674116098966 | operation: tanh | grad: 0.0
# epoch_loss: 1.2206517814262323
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 82
# predictions:
# label:  | data: -0.4649347148786799 | operation: tanh | grad: 0.0
# label:  | data: -0.5049914478215463 | operation: tanh | grad: 0.0
# label:  | data: -0.49630204931006405 | operation: tanh | grad: 0.0
# label:  | data: -0.5024815038523853 | operation: tanh | grad: 0.0
# epoch_loss: 1.218731167025437
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 83
# predictions:
# label:  | data: -0.4622012627702751 | operation: tanh | grad: 0.0
# label:  | data: -0.5048986965748167 | operation: tanh | grad: 0.0
# label:  | data: -0.49520696473995796 | operation: tanh | grad: 0.0
# label:  | data: -0.5020673961940155 | operation: tanh | grad: 0.0
# epoch_loss: 1.2166318140526597
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 84
# predictions:
# label:  | data: -0.45923361861984846 | operation: tanh | grad: 0.0
# label:  | data: -0.5048164429425088 | operation: tanh | grad: 0.0
# label:  | data: -0.49395842407445323 | operation: tanh | grad: 0.0
# label:  | data: -0.5016228034382835 | operation: tanh | grad: 0.0
# epoch_loss: 1.2143278444430758
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 85
# predictions:
# label:  | data: -0.45600174849879865 | operation: tanh | grad: 0.0
# label:  | data: -0.5047484882677158 | operation: tanh | grad: 0.0
# label:  | data: -0.4925232107106421 | operation: tanh | grad: 0.0
# label:  | data: -0.5011454910583015 | operation: tanh | grad: 0.0
# epoch_loss: 1.2117882772873558
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 86
# predictions:
# label:  | data: -0.45247071586473353 | operation: tanh | grad: 0.0
# label:  | data: -0.5046998594105121 | operation: tanh | grad: 0.0
# label:  | data: -0.4908586097862722 | operation: tanh | grad: 0.0
# label:  | data: -0.5006334263895782 | operation: tanh | grad: 0.0
# epoch_loss: 1.2089757101330698
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 87
# predictions:
# label:  | data: -0.44859971857089076 | operation: tanh | grad: 0.0
# label:  | data: -0.5046772441679099 | operation: tanh | grad: 0.0
# label:  | data: -0.4889090050116948 | operation: tanh | grad: 0.0
# label:  | data: -0.5000850224386936 | operation: tanh | grad: 0.0
# epoch_loss: 1.2058445721811468
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 88
# predictions:
# label:  | data: -0.44434091936856435 | operation: tanh | grad: 0.0
# label:  | data: -0.5046896080523585 | operation: tanh | grad: 0.0
# label:  | data: -0.48660101516394133 | operation: tanh | grad: 0.0
# label:  | data: -0.49949952727013514 | operation: tanh | grad: 0.0
# epoch_loss: 1.2023387826976089
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 89
# predictions:
# label:  | data: -0.4396380332057549 | operation: tanh | grad: 0.0
# label:  | data: -0.5047490819936596 | operation: tanh | grad: 0.0
# label:  | data: -0.48383645129842795 | operation: tanh | grad: 0.0
# label:  | data: -0.498877644306663 | operation: tanh | grad: 0.0
# epoch_loss: 1.1983885753580081
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 90
# predictions:
# label:  | data: -0.4344246412238118 | operation: tanh | grad: 0.0
# label:  | data: -0.5048722625670052 | operation: tanh | grad: 0.0
# label:  | data: -0.480481993103476 | operation: tanh | grad: 0.0
# label:  | data: -0.4982225230222444 | operation: tanh | grad: 0.0
# epoch_loss: 1.1939061461726046
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 91
# predictions:
# label:  | data: -0.42862222729261107 | operation: tanh | grad: 0.0
# label:  | data: -0.5050821530281749 | operation: tanh | grad: 0.0
# label:  | data: -0.4763539070448319 | operation: tanh | grad: 0.0
# label:  | data: -0.49754135131766103 | operation: tanh | grad: 0.0
# epoch_loss: 1.188779643975484
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 92
# predictions:
# label:  | data: -0.42213800243765526 | operation: tanh | grad: 0.0
# label:  | data: -0.5054111197342127 | operation: tanh | grad: 0.0
# label:  | data: -0.4711953149824649 | operation: tanh | grad: 0.0
# label:  | data: -0.4968479380864457 | operation: tanh | grad: 0.0
# epoch_loss: 1.1828648603151974
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 93
# predictions:
# label:  | data: -0.41486274626353514 | operation: tanh | grad: 0.0
# label:  | data: -0.5059054863587048 | operation: tanh | grad: 0.0
# label:  | data: -0.4646425509375245 | operation: tanh | grad: 0.0
# label:  | data: -0.4961669438674034 | operation: tanh | grad: 0.0
# epoch_loss: 1.1759738637627635
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 94
# predictions:
# label:  | data: -0.4066692537114107 | operation: tanh | grad: 0.0
# label:  | data: -0.5066328009874849 | operation: tanh | grad: 0.0
# label:  | data: -0.45617660489567874 | operation: tanh | grad: 0.0
# label:  | data: -0.4955408700288599 | operation: tanh | grad: 0.0
# epoch_loss: 1.1678600222722224
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 95
# predictions:
# label:  | data: -0.3974127122426919 | operation: tanh | grad: 0.0
# label:  | data: -0.5076934540498369 | operation: tanh | grad: 0.0
# label:  | data: -0.44505778613207214 | operation: tanh | grad: 0.0
# label:  | data: -0.49504162674454627 | operation: tanh | grad: 0.0
# epoch_loss: 1.1582001267851896
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 96
# predictions:
# label:  | data: -0.3869356850630818 | operation: tanh | grad: 0.0
# label:  | data: -0.5092391306251948 | operation: tanh | grad: 0.0
# label:  | data: -0.43025337873390146 | operation: tanh | grad: 0.0
# label:  | data: -0.4947893949684624 | operation: tanh | grad: 0.0
# epoch_loss: 1.146578572377199
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 97
# predictions:
# label:  | data: -0.37508222247643974 | operation: tanh | grad: 0.0
# label:  | data: -0.5115007799702926 | operation: tanh | grad: 0.0
# label:  | data: -0.41040604832011074 | operation: tanh | grad: 0.0
# label:  | data: -0.4949817275380629 | operation: tanh | grad: 0.0
# epoch_loss: 1.1324894066544904
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 98
# predictions:
# label:  | data: -0.3617255177766928 | operation: tanh | grad: 0.0
# label:  | data: -0.5148250677521297 | operation: tanh | grad: 0.0
# label:  | data: -0.38398111883018 | operation: tanh | grad: 0.0
# label:  | data: -0.49593172703175475 | operation: tanh | grad: 0.0
# epoch_loss: 1.1153918221432337
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 99
# predictions:
# label:  | data: -0.3468006786571399 | operation: tanh | grad: 0.0
# label:  | data: -0.5197009751401548 | operation: tanh | grad: 0.0
# label:  | data: -0.3498496621718098 | operation: tanh | grad: 0.0
# label:  | data: -0.49809497140259346 | operation: tanh | grad: 0.0
# epoch_loss: 1.0948651787213586
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 100
# predictions:
# label:  | data: -0.3302838657085449 | operation: tanh | grad: 0.0
# label:  | data: -0.5267135258515435 | operation: tanh | grad: 0.0
# label:  | data: -0.3084245084353781 | operation: tanh | grad: 0.0
# label:  | data: -0.5020153841729665 | operation: tanh | grad: 0.0
# epoch_loss: 1.0708356383193158
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 101
# predictions:
# label:  | data: -0.3119797037126786 | operation: tanh | grad: 0.0
# label:  | data: -0.5363219177370703 | operation: tanh | grad: 0.0
# label:  | data: -0.2625277822997371 | operation: tanh | grad: 0.0
# label:  | data: -0.5080763419856206 | operation: tanh | grad: 0.0
# epoch_loss: 1.0436384983110905
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 102
# predictions:
# label:  | data: -0.2910799000514672 | operation: tanh | grad: 0.0
# label:  | data: -0.5485058822538714 | operation: tanh | grad: 0.0
# label:  | data: -0.21634082134348157 | operation: tanh | grad: 0.0
# ...
# label:  | data: -0.9967517940963259 | operation: tanh | grad: 0.0
# label:  | data: -0.0013661687357206934 | operation: tanh | grad: 0.0
# label:  | data: -0.995183792095817 | operation: tanh | grad: 0.0
# epoch_loss: 0.2519850186131032
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 467
# predictions:
# label:  | data: 0.9625489510739071 | operation: tanh | grad: 0.0
# label:  | data: -0.996761199909407 | operation: tanh | grad: 0.0
# label:  | data: -0.0007564663535523096 | operation: tanh | grad: 0.0
# label:  | data: -0.9951951549915324 | operation: tanh | grad: 0.0
# epoch_loss: 0.25197858246244426
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 468
# predictions:
# label:  | data: 0.962597144787975 | operation: tanh | grad: 0.0
# label:  | data: -0.9967725364728058 | operation: tanh | grad: 0.0
# label:  | data: -0.0012275779267802531 | operation: tanh | grad: 0.0
# label:  | data: -0.9952100212631464 | operation: tanh | grad: 0.0
# epoch_loss: 0.2519721919992714
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 469
# predictions:
# label:  | data: 0.9626644273130207 | operation: tanh | grad: 0.0
# label:  | data: -0.9967822309478243 | operation: tanh | grad: 0.0
# label:  | data: -0.0008453893972057841 | operation: tanh | grad: 0.0
# label:  | data: -0.9952219955551708 | operation: tanh | grad: 0.0
# epoch_loss: 0.25196584528489924
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 470
# predictions:
# label:  | data: 0.9627162203095836 | operation: tanh | grad: 0.0
# label:  | data: -0.9967930970464138 | operation: tanh | grad: 0.0
# label:  | data: -0.0011394331665285785 | operation: tanh | grad: 0.0
# label:  | data: -0.9952361189958844 | operation: tanh | grad: 0.0
# epoch_loss: 0.251959540807973
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 471
# predictions:
# label:  | data: 0.9627799018548541 | operation: tanh | grad: 0.0
# label:  | data: -0.9968029133171222 | operation: tanh | grad: 0.0
# label:  | data: -0.0008958461923174357 | operation: tanh | grad: 0.0
# label:  | data: -0.9952484060917732 | operation: tanh | grad: 0.0
# epoch_loss: 0.25195327765500425
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 472
# predictions:
# label:  | data: 0.9628337217366364 | operation: tanh | grad: 0.0
# label:  | data: -0.9968134420918987 | operation: tanh | grad: 0.0
# label:  | data: -0.001081354989618914 | operation: tanh | grad: 0.0
# label:  | data: -0.9952620210959672 | operation: tanh | grad: 0.0
# epoch_loss: 0.2519470549950408
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 473
# predictions:
# label:  | data: 0.9628950229428854 | operation: tanh | grad: 0.0
# label:  | data: -0.9968232826138468 | operation: tanh | grad: 0.0
# label:  | data: -0.0009233579553928211 | operation: tanh | grad: 0.0
# label:  | data: -0.9952744451555364 | operation: tanh | grad: 0.0
# epoch_loss: 0.2519408722716422
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 474
# predictions:
# label:  | data: 0.962949931718685 | operation: tanh | grad: 0.0
# label:  | data: -0.9968335543733451 | operation: tanh | grad: 0.0
# label:  | data: -0.001041458665866964 | operation: tanh | grad: 0.0
# label:  | data: -0.9952876925285008 | operation: tanh | grad: 0.0
# epoch_loss: 0.25193472891718127
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 475
# predictions:
# label:  | data: 0.9630095882482023 | operation: tanh | grad: 0.0
# label:  | data: -0.9968433617697671 | operation: tanh | grad: 0.0
# label:  | data: -0.0009370315539889655 | operation: tanh | grad: 0.0
# label:  | data: -0.9953001490221286 | operation: tanh | grad: 0.0
# epoch_loss: 0.25192862450357423
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 476
# predictions:
# label:  | data: 0.9630650197052618 | operation: tanh | grad: 0.0
# label:  | data: -0.9968534259527774 | operation: tanh | grad: 0.0
# label:  | data: -0.0010127240067585137 | operation: tanh | grad: 0.0
# label:  | data: -0.9953131148099539 | operation: tanh | grad: 0.0
# epoch_loss: 0.25192255857368784
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 477
# predictions:
# label:  | data: 0.9631234812384305 | operation: tanh | grad: 0.0
# label:  | data: -0.996863166409177 | operation: tanh | grad: 0.0
# label:  | data: -0.0009422770254794259 | operation: tanh | grad: 0.0
# label:  | data: -0.9953255411527978 | operation: tanh | grad: 0.0
# epoch_loss: 0.25191653074852555
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 478
# predictions:
# label:  | data: 0.9631790897874527 | operation: tanh | grad: 0.0
# label:  | data: -0.9968730541774738 | operation: tanh | grad: 0.0
# label:  | data: -0.000990951443899933 | operation: tanh | grad: 0.0
# label:  | data: -0.9953382789447939 | operation: tanh | grad: 0.0
# epoch_loss: 0.2519105406230176
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 479
# predictions:
# label:  | data: 0.9632366352454729 | operation: tanh | grad: 0.0
# label:  | data: -0.9968827078649388 | operation: tanh | grad: 0.0
# label:  | data: -0.000942347526866121 | operation: tanh | grad: 0.0
# label:  | data: -0.9953506375244516 | operation: tanh | grad: 0.0
# epoch_loss: 0.25190458783968556
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 480
# predictions:
# label:  | data: 0.9632922078485417 | operation: tanh | grad: 0.0
# label:  | data: -0.9968924394135901 | operation: tanh | grad: 0.0
# label:  | data: -0.0009735970447637671 | operation: tanh | grad: 0.0
# label:  | data: -0.9953631814226549 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518986720219944
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 481
# predictions:
# label:  | data: 0.9633490129303801 | operation: tanh | grad: 0.0
# label:  | data: -0.9969019948977818 | operation: tanh | grad: 0.0
# label:  | data: -0.000939222540532579 | operation: tanh | grad: 0.0
# label:  | data: -0.9953754496695895 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518927928244917
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 482
# predictions:
# label:  | data: 0.9634044171602864 | operation: tanh | grad: 0.0
# label:  | data: -0.9969115837511737 | operation: tanh | grad: 0.0
# label:  | data: -0.0009591004672471345 | operation: tanh | grad: 0.0
# label:  | data: -0.9953878219234997 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518869498890682
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 483
# predictions:
# label:  | data: 0.963460594407465 | operation: tanh | grad: 0.0
# label:  | data: -0.9969210346888906 | operation: tanh | grad: 0.0
# label:  | data: -0.0009341204536430555 | operation: tanh | grad: 0.0
# label:  | data: -0.9953999864318434 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518811428791277
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 484
# predictions:
# label:  | data: 0.9635157474486465 | operation: tanh | grad: 0.0
# label:  | data: -0.9969304902560795 | operation: tanh | grad: 0.0
# label:  | data: -0.0009464926704691029 | operation: tanh | grad: 0.0
# label:  | data: -0.9954122019870901 | operation: tanh | grad: 0.0
# epoch_loss: 0.25187537145028055
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 485
# predictions:
# label:  | data: 0.9635713702950361 | operation: tanh | grad: 0.0
# label:  | data: -0.9969398334204403 | operation: tanh | grad: 0.0
# label:  | data: -0.0009277995279164502 | operation: tanh | grad: 0.0
# label:  | data: -0.9954242549925044 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518696352737832
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 486
# predictions:
# label:  | data: 0.9636262202247436 | operation: tanh | grad: 0.0
# label:  | data: -0.9969491625334287 | operation: tanh | grad: 0.0
# label:  | data: -0.0009351642537952109 | operation: tanh | grad: 0.0
# label:  | data: -0.9954363242331733 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518639340165537
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 487
# predictions:
# label:  | data: 0.9636813376013909 | operation: tanh | grad: 0.0
# label:  | data: -0.9969583966197568 | operation: tanh | grad: 0.0
# label:  | data: -0.0009207366567871535 | operation: tanh | grad: 0.0
# label:  | data: -0.9954482614783611 | operation: tanh | grad: 0.0
# epoch_loss: 0.25185826735739847
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 488
# predictions:
# label:  | data: 0.9637358519552117 | operation: tanh | grad: 0.0
# label:  | data: -0.9969676044705795 | operation: tanh | grad: 0.0
# label:  | data: -0.0009247270840866121 | operation: tanh | grad: 0.0
# label:  | data: -0.9954601918997602 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518526349731673
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 489
# predictions:
# label:  | data: 0.963790497261063 | operation: tanh | grad: 0.0
# label:  | data: -0.9969767293663092 | operation: tanh | grad: 0.0
# label:  | data: -0.0009132347390961328 | operation: tanh | grad: 0.0
# label:  | data: -0.9954720113262866 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518470365501063
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 490
# predictions:
# label:  | data: 0.9638446559684427 | operation: tanh | grad: 0.0
# label:  | data: -0.9969858200846885 | operation: tanh | grad: 0.0
# label:  | data: -0.0009149307135487609 | operation: tanh | grad: 0.0
# label:  | data: -0.9954838085671758 | operation: tanh | grad: 0.0
# epoch_loss: 0.25184147177412336
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 491
# predictions:
# label:  | data: 0.9638988526423772 | operation: tanh | grad: 0.0
# label:  | data: -0.9969948364181768 | operation: tanh | grad: 0.0
# label:  | data: -0.000905487893035655 | operation: tanh | grad: 0.0
# label:  | data: -0.9954955095048783 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518359403388204
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 492
# predictions:
# label:  | data: 0.9639526436130433 | operation: tanh | grad: 0.0
# label:  | data: -0.9970038134318613 | operation: tanh | grad: 0.0
# label:  | data: -0.000905611334185499 | operation: tanh | grad: 0.0
# label:  | data: -0.9955071779917938 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518304419385507
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 493
# predictions:
# label:  | data: 0.9640064086330195 | operation: tanh | grad: 0.0
# label:  | data: -0.9970127222906952 | operation: tanh | grad: 0.0
# label:  | data: -0.0008976214970779948 | operation: tanh | grad: 0.0
# label:  | data: -0.9955187606511399 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518249762741674
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 494
# predictions:
# label:  | data: 0.9640598249691265 | operation: tanh | grad: 0.0
# label:  | data: -0.9970215885529504 | operation: tanh | grad: 0.0
# label:  | data: -0.0008966602639751888 | operation: tanh | grad: 0.0
# label:  | data: -0.9955303040052124 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518195430480029
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 495
# predictions:
# label:  | data: 0.9641131710733417 | operation: tanh | grad: 0.0
# label:  | data: -0.9970303913063734 | operation: tanh | grad: 0.0
# label:  | data: -0.0008897170385676339 | operation: tanh | grad: 0.0
# label:  | data: -0.995541769156107 | operation: tanh | grad: 0.0
# epoch_loss: 0.2518141419680309
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 496
# predictions:
# label:  | data: 0.964166209289373 | operation: tanh | grad: 0.0
# label:  | data: -0.9970391494413682 | operation: tanh | grad: 0.0
# label:  | data: -0.0008880042832641456 | operation: tanh | grad: 0.0
# label:  | data: -0.9955531904528779 | operation: tanh | grad: 0.0
# epoch_loss: 0.25180877274418567
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 497
# predictions:
# label:  | data: 0.9642191464011151 | operation: tanh | grad: 0.0
# label:  | data: -0.9970478476273432 | operation: tanh | grad: 0.0
# label:  | data: -0.0008818276964539136 | operation: tanh | grad: 0.0
# label:  | data: -0.9955645392194374 | operation: tanh | grad: 0.0
# epoch_loss: 0.251803435091408
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 498
# predictions:
# label:  | data: 0.9642718052750968 | operation: tanh | grad: 0.0
# label:  | data: -0.9970565000242453 | operation: tanh | grad: 0.0
# label:  | data: -0.0008795932363470185 | operation: tanh | grad: 0.0
# label:  | data: -0.9955758411567216 | operation: tanh | grad: 0.0
# epoch_loss: 0.2517981287269123
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 499
# predictions:
# label:  | data: 0.9643243414262329 | operation: tanh | grad: 0.0
# label:  | data: -0.9970650952770562 | operation: tanh | grad: 0.0
# label:  | data: -0.0008739882140851745 | operation: tanh | grad: 0.0
# label:  | data: -0.995587074884927 | operation: tanh | grad: 0.0
# epoch_loss: 0.2517928533724405
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Slightly Complex Function
#
# $$f(x, y, z) = (x^2 + y) * (z + 1)$$

# %%
neural_network3 = MultiLayerPerceptron(num_inputs=3, num_neurons_per_layer=[4, 4, 1])

# %%
# data_point1 = [1, 1, 1]  => (x^2 + y) * (z + 1) = (1 + 1) * (1 + 1) => target = 4
# data_point2 = [0, 2, 4]  => (x^2 + y) * (z + 1) = (0 + 2) * (4 + 1) => target = 10
# data_point3 = [-2, 4, 2] => (x^2 + y) * (z + 1) = (4 - 4) * (2 + 1) => target = 0
# data_point4 = [3, 1, 2]  => (x^2 + y) * (z + 1) = (9 + 1) * (2 + 1) => target = 30
inputs3 = [[1, 1, 1], [0, 2, 4], [2, -4, 2], [3, 1, 2]]
targets3 = [4, 10, 0, 30]

# %%
initial_predictions3 = [neural_network3(input)[0] for input in inputs3]
initial_predictions3
# Out:
# [label:  | data: 0.9628255159712698 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9684080085104759 | operation: tanh | grad: 0.0,
#  label:  | data: -0.9501289670734312 | operation: tanh | grad: 0.0,
#  label:  | data: 0.9666568915540642 | operation: tanh | grad: 0.0]

# %%
# Notice that the neural network is not able to learn the function at all. This function might be way too
# complex for this neural network to all.
train_model(model=neural_network3, inputs=inputs3, targets=targets3, num_epochs=100, learning_rate=1)
# Out:
# epoch: 0
# predictions:
# label:  | data: 0.9628255159712698 | operation: tanh | grad: 0.0
# label:  | data: 0.9684080085104759 | operation: tanh | grad: 0.0
# label:  | data: -0.9501289670734312 | operation: tanh | grad: 0.0
# label:  | data: 0.9666568915540642 | operation: tanh | grad: 0.0
# epoch_loss: 233.65795996349752
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 1
# predictions:
# label:  | data: 0.9999998874667465 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998960044133 | operation: tanh | grad: 0.0
# label:  | data: -0.9995868347154776 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998953813926 | operation: tanh | grad: 0.0
# epoch_loss: 232.99979561378396
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 2
# predictions:
# label:  | data: 0.9999998872690272 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998958177811 | operation: tanh | grad: 0.0
# label:  | data: -0.9995612700843419 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998951945572 | operation: tanh | grad: 0.0
# epoch_loss: 232.99978284075854
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 3
# predictions:
# label:  | data: 0.9999998870600426 | operation: tanh | grad: 0.0
# label:  | data: 0.999999895620388 | operation: tanh | grad: 0.0
# label:  | data: -0.999531174376436 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998949969763 | operation: tanh | grad: 0.0
# epoch_loss: 232.99976780379964
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 4
# predictions:
# label:  | data: 0.9999998868379159 | operation: tanh | grad: 0.0
# label:  | data: 0.99999989541043 | operation: tanh | grad: 0.0
# label:  | data: -0.9994951523806559 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998947868498 | operation: tanh | grad: 0.0
# epoch_loss: 232.999749805895
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 5
# predictions:
# label:  | data: 0.9999998866002203 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998951855709 | operation: tanh | grad: 0.0
# label:  | data: -0.9994511612923498 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998945618482 | operation: tanh | grad: 0.0
# epoch_loss: 232.99972782656994
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 6
# predictions:
# label:  | data: 0.9999998863437327 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998949427028 | operation: tanh | grad: 0.0
# label:  | data: -0.9993960849944858 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998943188741 | operation: tanh | grad: 0.0
# epoch_loss: 232.99970030929413
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 7
# predictions:
# label:  | data: 0.9999998860640337 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998946775596 | operation: tanh | grad: 0.0
# label:  | data: -0.9993249235028179 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998940536741 | operation: tanh | grad: 0.0
# epoch_loss: 232.99966475676018
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 8
# predictions:
# label:  | data: 0.9999998857548165 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998943840419 | operation: tanh | grad: 0.0
# label:  | data: -0.9992291241287469 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998937601716 | operation: tanh | grad: 0.0
# epoch_loss: 232.9996168977439
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 9
# predictions:
# label:  | data: 0.9999998854066151 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998940529741 | operation: tanh | grad: 0.0
# label:  | data: -0.9990927843639381 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998934292261 | operation: tanh | grad: 0.0
# epoch_loss: 232.99954879186993
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 10
# predictions:
# label:  | data: 0.999999885004237 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998936695907 | operation: tanh | grad: 0.0
# label:  | data: -0.9988827882284457 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998930461377 | operation: tanh | grad: 0.0
# epoch_loss: 232.99944390796625
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 11
# predictions:
# label:  | data: 0.9999998845209533 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998932078221 | operation: tanh | grad: 0.0
# label:  | data: -0.9985179800873294 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998925849641 | operation: tanh | grad: 0.0
# epoch_loss: 232.99926175044084
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 12
# predictions:
# label:  | data: 0.9999998839030116 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998926149863 | operation: tanh | grad: 0.0
# label:  | data: -0.9977418526227883 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998919933225 | operation: tanh | grad: 0.0
# epoch_loss: 232.99887442459365
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 13
# predictions:
# label:  | data: 0.9999998830168796 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998917592173 | operation: tanh | grad: 0.0
# label:  | data: -0.9952730500968995 | operation: tanh | grad: 0.0
# label:  | data: 0.999999891140237 | operation: tanh | grad: 0.0
# epoch_loss: 232.9976443520871
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 14
# predictions:
# label:  | data: 0.9999998813775298 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998901545374 | operation: tanh | grad: 0.0
# label:  | data: -0.9720915976418449 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998895439579 | operation: tanh | grad: 0.0
# epoch_loss: 232.98624279240238
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 15
# predictions:
# label:  | data: 0.9999998750038787 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998836080691 | operation: tanh | grad: 0.0
# label:  | data: 0.7298451872787477 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998830703859 | operation: tanh | grad: 0.0
# epoch_loss: 232.88317090608575
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 16
# predictions:
# label:  | data: 0.9999998376351832 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998564446517 | operation: tanh | grad: 0.0
# label:  | data: -0.9999356854610698 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998541552851 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997084805932
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 17
# predictions:
# label:  | data: 0.9999998375919416 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998564054174 | operation: tanh | grad: 0.0
# label:  | data: -0.9999356150926235 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998541156025 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997081369415
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 18
# predictions:
# label:  | data: 0.9999998375486372 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998563661259 | operation: tanh | grad: 0.0
# label:  | data: -0.999935544544377 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998540758621 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997077924027
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 19
# predictions:
# label:  | data: 0.9999998375052699 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998563267767 | operation: tanh | grad: 0.0
# label:  | data: -0.9999354738156067 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998540360636 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997074469744
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 20
# predictions:
# label:  | data: 0.9999998374618395 | operation: tanh | grad: 0.0
# label:  | data: 0.99999985628737 | operation: tanh | grad: 0.0
# label:  | data: -0.9999354029055851 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998539962067 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997071006507
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 21
# predictions:
# label:  | data: 0.9999998374183461 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998562479053 | operation: tanh | grad: 0.0
# label:  | data: -0.9999353318135806 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998539562917 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997067534295
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 22
# predictions:
# label:  | data: 0.9999998373747893 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998562083827 | operation: tanh | grad: 0.0
# label:  | data: -0.9999352605388581 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998539163181 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999706405307
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 23
# predictions:
# label:  | data: 0.999999837331169 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998561688017 | operation: tanh | grad: 0.0
# label:  | data: -0.999935189080678 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998538762855 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997060562796
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 24
# predictions:
# label:  | data: 0.9999998372874849 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998561291626 | operation: tanh | grad: 0.0
# label:  | data: -0.9999351174382969 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998538361943 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997057063433
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 25
# predictions:
# label:  | data: 0.9999998372437368 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998560894651 | operation: tanh | grad: 0.0
# label:  | data: -0.9999350456109668 | operation: tanh | grad: 0.0
# label:  | data: 0.999999853796044 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997053554944
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 26
# predictions:
# label:  | data: 0.9999998371999247 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998560497089 | operation: tanh | grad: 0.0
# label:  | data: -0.9999349735979363 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998537558344 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997050037294
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 27
# predictions:
# label:  | data: 0.9999998371560485 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998560098938 | operation: tanh | grad: 0.0
# label:  | data: -0.9999349013984489 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998537155654 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999704651044
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 28
# predictions:
# label:  | data: 0.9999998371121077 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998559700198 | operation: tanh | grad: 0.0
# label:  | data: -0.999934829011745 | operation: tanh | grad: 0.0
# label:  | data: 0.999999853675237 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999704297435
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 29
# predictions:
# label:  | data: 0.9999998370681024 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998559300866 | operation: tanh | grad: 0.0
# label:  | data: -0.99993475643706 | operation: tanh | grad: 0.0
# label:  | data: 0.999999853634849 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997039428985
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 30
# predictions:
# label:  | data: 0.9999998370240321 | operation: tanh | grad: 0.0
# label:  | data: 0.999999855890094 | operation: tanh | grad: 0.0
# label:  | data: -0.999934683673625 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998535944009 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997035874313
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 31
# predictions:
# label:  | data: 0.9999998369798969 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998558500421 | operation: tanh | grad: 0.0
# label:  | data: -0.9999346107206678 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998535538926 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997032310284
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 32
# predictions:
# label:  | data: 0.9999998369356968 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998558099308 | operation: tanh | grad: 0.0
# label:  | data: -0.9999345375774106 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998535133244 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997028736865
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 33
# predictions:
# label:  | data: 0.999999836891431 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998557697595 | operation: tanh | grad: 0.0
# label:  | data: -0.999934464243072 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998534726959 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997025154016
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 34
# predictions:
# label:  | data: 0.9999998368471001 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998557295282 | operation: tanh | grad: 0.0
# label:  | data: -0.9999343907168659 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998534320067 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997021561694
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 35
# predictions:
# label:  | data: 0.9999998368027032 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998556892367 | operation: tanh | grad: 0.0
# label:  | data: -0.9999343169980024 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998533912567 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997017959876
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 36
# predictions:
# label:  | data: 0.9999998367582404 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998556488848 | operation: tanh | grad: 0.0
# label:  | data: -0.9999342430856869 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998533504459 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997014348506
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 37
# predictions:
# label:  | data: 0.9999998367137117 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998556084728 | operation: tanh | grad: 0.0
# label:  | data: -0.9999341689791191 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998533095742 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997010727546
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 38
# predictions:
# label:  | data: 0.9999998366691167 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998555679998 | operation: tanh | grad: 0.0
# label:  | data: -0.9999340946774967 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998532686408 | operation: tanh | grad: 0.0
# epoch_loss: 232.99997007096968
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 39
# predictions:
# label:  | data: 0.9999998366244555 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998555274661 | operation: tanh | grad: 0.0
# label:  | data: -0.9999340201800105 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998532276464 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999700345672
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 40
# predictions:
# label:  | data: 0.9999998365797272 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998554868715 | operation: tanh | grad: 0.0
# label:  | data: -0.999933945485848 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998531865905 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996999806768
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 41
# predictions:
# label:  | data: 0.9999998365349324 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998554462158 | operation: tanh | grad: 0.0
# label:  | data: -0.9999338705941917 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998531454726 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999699614707
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 42
# predictions:
# label:  | data: 0.9999998364900706 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998554054985 | operation: tanh | grad: 0.0
# label:  | data: -0.9999337955042199 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998531042928 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999699247758
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 43
# predictions:
# label:  | data: 0.9999998364451417 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998553647199 | operation: tanh | grad: 0.0
# label:  | data: -0.9999337202151056 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998530630511 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996988798262
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 44
# predictions:
# label:  | data: 0.9999998364001452 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998553238795 | operation: tanh | grad: 0.0
# label:  | data: -0.9999336447260174 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998530217469 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996985109075
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 45
# predictions:
# label:  | data: 0.9999998363550809 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998552829773 | operation: tanh | grad: 0.0
# label:  | data: -0.9999335690361194 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998529803802 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999698140998
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 46
# predictions:
# label:  | data: 0.9999998363099493 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998552420131 | operation: tanh | grad: 0.0
# label:  | data: -0.999933493144571 | operation: tanh | grad: 0.0
# label:  | data: 0.999999852938951 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999697770093
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 47
# predictions:
# label:  | data: 0.9999998362647495 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998552009866 | operation: tanh | grad: 0.0
# label:  | data: -0.9999334170505261 | operation: tanh | grad: 0.0
# label:  | data: 0.999999852897459 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996973981885
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 48
# predictions:
# label:  | data: 0.9999998362194816 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998551598976 | operation: tanh | grad: 0.0
# label:  | data: -0.9999333407531341 | operation: tanh | grad: 0.0
# label:  | data: 0.999999852855904 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996970252806
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 49
# predictions:
# label:  | data: 0.9999998361741455 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998551187462 | operation: tanh | grad: 0.0
# label:  | data: -0.9999332642515403 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998528142856 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996966513652
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 50
# predictions:
# label:  | data: 0.9999998361287409 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998550775321 | operation: tanh | grad: 0.0
# label:  | data: -0.999933187544884 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998527726043 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996962764368
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 51
# predictions:
# label:  | data: 0.9999998360832674 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998550362549 | operation: tanh | grad: 0.0
# label:  | data: -0.9999331106323001 | operation: tanh | grad: 0.0
# label:  | data: 0.999999852730859 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999695900492
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 52
# predictions:
# label:  | data: 0.9999998360377249 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998549949146 | operation: tanh | grad: 0.0
# label:  | data: -0.9999330335129184 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998526890501 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996955235267
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 53
# predictions:
# label:  | data: 0.9999998359921135 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998549535113 | operation: tanh | grad: 0.0
# label:  | data: -0.9999329561858643 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998526471774 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996951455358
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 54
# predictions:
# label:  | data: 0.9999998359464324 | operation: tanh | grad: 0.0
# label:  | data: 0.999999854912044 | operation: tanh | grad: 0.0
# label:  | data: -0.9999328786502568 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998526052405 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999694766516
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 55
# predictions:
# label:  | data: 0.9999998359006822 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998548705135 | operation: tanh | grad: 0.0
# label:  | data: -0.9999328009052111 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998525632396 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996943864625
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 56
# predictions:
# label:  | data: 0.9999998358548621 | operation: tanh | grad: 0.0
# label:  | data: 0.999999854828919 | operation: tanh | grad: 0.0
# label:  | data: -0.9999327229498369 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998525211738 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996940053703
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 57
# predictions:
# label:  | data: 0.999999835808972 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998547872604 | operation: tanh | grad: 0.0
# label:  | data: -0.9999326447832383 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998524790437 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996936232358
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 58
# predictions:
# label:  | data: 0.9999998357630117 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998547455374 | operation: tanh | grad: 0.0
# label:  | data: -0.9999325664045149 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998524368486 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996932400538
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 59
# predictions:
# label:  | data: 0.9999998357169814 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998547037502 | operation: tanh | grad: 0.0
# label:  | data: -0.9999324878127606 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998523945887 | operation: tanh | grad: 0.0
# epoch_loss: 232.999969285582
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 60
# predictions:
# label:  | data: 0.9999998356708802 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998546618984 | operation: tanh | grad: 0.0
# label:  | data: -0.9999324090070643 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998523522634 | operation: tanh | grad: 0.0
# epoch_loss: 232.999969247053
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 61
# predictions:
# label:  | data: 0.9999998356247085 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998546199819 | operation: tanh | grad: 0.0
# label:  | data: -0.9999323299865095 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998523098726 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996920841795
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 62
# predictions:
# label:  | data: 0.9999998355784656 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998545780004 | operation: tanh | grad: 0.0
# label:  | data: -0.9999322507501739 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998522674163 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996916967638
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 63
# predictions:
# label:  | data: 0.9999998355321519 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998545359536 | operation: tanh | grad: 0.0
# label:  | data: -0.999932171297131 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998522248943 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996913082776
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 64
# predictions:
# label:  | data: 0.9999998354857665 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998544938414 | operation: tanh | grad: 0.0
# label:  | data: -0.9999320916264474 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998521823062 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996909187175
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 65
# predictions:
# label:  | data: 0.9999998354393096 | operation: tanh | grad: 0.0
# label:  | data: 0.999999854451664 | operation: tanh | grad: 0.0
# label:  | data: -0.9999320117371854 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998521396519 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999690528078
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 66
# predictions:
# label:  | data: 0.9999998353927811 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998544094206 | operation: tanh | grad: 0.0
# label:  | data: -0.999931931628401 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998520969312 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996901363548
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 67
# predictions:
# label:  | data: 0.9999998353461804 | operation: tanh | grad: 0.0
# label:  | data: 0.999999854367111 | operation: tanh | grad: 0.0
# label:  | data: -0.9999318512991454 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998520541441 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996897435426
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 68
# predictions:
# label:  | data: 0.9999998352995078 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998543247357 | operation: tanh | grad: 0.0
# label:  | data: -0.9999317707484637 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998520112902 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999689349638
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 69
# predictions:
# label:  | data: 0.9999998352527625 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998542822939 | operation: tanh | grad: 0.0
# label:  | data: -0.9999316899753954 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998519683692 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996889546347
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 70
# predictions:
# label:  | data: 0.9999998352059446 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998542397857 | operation: tanh | grad: 0.0
# label:  | data: -0.9999316089789746 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998519253811 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996885585284
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 71
# predictions:
# label:  | data: 0.9999998351590541 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998541972106 | operation: tanh | grad: 0.0
# label:  | data: -0.999931527758229 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998518823258 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996881613149
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 72
# predictions:
# label:  | data: 0.9999998351120902 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998541545686 | operation: tanh | grad: 0.0
# label:  | data: -0.9999314463121818 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998518392028 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996877629889
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 73
# predictions:
# label:  | data: 0.9999998350650533 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998541118597 | operation: tanh | grad: 0.0
# label:  | data: -0.999931364639849 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998517960121 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996873635453
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 74
# predictions:
# label:  | data: 0.9999998350179429 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998540690832 | operation: tanh | grad: 0.0
# label:  | data: -0.999931282740242 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998517527534 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996869629794
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 75
# predictions:
# label:  | data: 0.9999998349707587 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998540262394 | operation: tanh | grad: 0.0
# label:  | data: -0.9999312006123653 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998517094265 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996865612866
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 76
# predictions:
# label:  | data: 0.9999998349235005 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998539833276 | operation: tanh | grad: 0.0
# label:  | data: -0.9999311182552181 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998516660312 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996861584611
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 77
# predictions:
# label:  | data: 0.9999998348761682 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998539403482 | operation: tanh | grad: 0.0
# label:  | data: -0.9999310356677931 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998516225675 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996857544986
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 78
# predictions:
# label:  | data: 0.9999998348287615 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998538973004 | operation: tanh | grad: 0.0
# label:  | data: -0.999930952849078 | operation: tanh | grad: 0.0
# label:  | data: 0.999999851579035 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996853493946
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 79
# predictions:
# label:  | data: 0.9999998347812805 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998538541844 | operation: tanh | grad: 0.0
# label:  | data: -0.9999308697980529 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998515354335 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996849431423
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 80
# predictions:
# label:  | data: 0.9999998347337243 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998538109999 | operation: tanh | grad: 0.0
# label:  | data: -0.999930786513693 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998514917626 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996845357387
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 81
# predictions:
# label:  | data: 0.9999998346860933 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998537677465 | operation: tanh | grad: 0.0
# label:  | data: -0.9999307029949673 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998514480226 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996841271766
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 82
# predictions:
# label:  | data: 0.9999998346383869 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998537244245 | operation: tanh | grad: 0.0
# label:  | data: -0.9999306192408377 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998514042128 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999683717453
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 83
# predictions:
# label:  | data: 0.9999998345906052 | operation: tanh | grad: 0.0
# label:  | data: 0.999999853681033 | operation: tanh | grad: 0.0
# label:  | data: -0.9999305352502608 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998513603334 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996833065612
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 84
# predictions:
# label:  | data: 0.9999998345427478 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998536375723 | operation: tanh | grad: 0.0
# label:  | data: -0.9999304510221863 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998513163837 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999682894496
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 85
# predictions:
# label:  | data: 0.9999998344948144 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998535940418 | operation: tanh | grad: 0.0
# label:  | data: -0.999930366555558 | operation: tanh | grad: 0.0
# label:  | data: 0.999999851272364 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999682481253
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 86
# predictions:
# label:  | data: 0.9999998344468046 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998535504416 | operation: tanh | grad: 0.0
# label:  | data: -0.9999302818493128 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998512282737 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996820668267
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 87
# predictions:
# label:  | data: 0.9999998343987188 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998535067716 | operation: tanh | grad: 0.0
# label:  | data: -0.9999301969023814 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998511841126 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996816512112
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 88
# predictions:
# label:  | data: 0.9999998343505562 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998534630311 | operation: tanh | grad: 0.0
# label:  | data: -0.9999301117136885 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998511398811 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999681234402
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 89
# predictions:
# label:  | data: 0.9999998343023166 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998534192204 | operation: tanh | grad: 0.0
# label:  | data: -0.9999300262821516 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998510955782 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996808163934
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 90
# predictions:
# label:  | data: 0.9999998342539999 | operation: tanh | grad: 0.0
# label:  | data: 0.999999853375339 | operation: tanh | grad: 0.0
# label:  | data: -0.9999299406066813 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998510512038 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996803971794
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 91
# predictions:
# label:  | data: 0.9999998342056062 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998533313867 | operation: tanh | grad: 0.0
# label:  | data: -0.9999298546861825 | operation: tanh | grad: 0.0
# label:  | data: 0.999999851006758 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996799767555
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 92
# predictions:
# label:  | data: 0.9999998341571346 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998532873634 | operation: tanh | grad: 0.0
# label:  | data: -0.999929768519553 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998509622406 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996795551158
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 93
# predictions:
# label:  | data: 0.9999998341085853 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998532432686 | operation: tanh | grad: 0.0
# label:  | data: -0.9999296821056836 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998509176511 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999679132255
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 94
# predictions:
# label:  | data: 0.999999834059958 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998531991026 | operation: tanh | grad: 0.0
# label:  | data: -0.9999295954434587 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998508729896 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999678708167
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 95
# predictions:
# label:  | data: 0.9999998340112525 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998531548646 | operation: tanh | grad: 0.0
# label:  | data: -0.9999295085317552 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998508282556 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996782828467
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 96
# predictions:
# label:  | data: 0.9999998339624683 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998531105546 | operation: tanh | grad: 0.0
# label:  | data: -0.9999294213694443 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998507834488 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996778562885
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 97
# predictions:
# label:  | data: 0.9999998339136055 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998530661726 | operation: tanh | grad: 0.0
# label:  | data: -0.9999293339553886 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998507385692 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996774284872
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 98
# predictions:
# label:  | data: 0.9999998338646636 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998530217182 | operation: tanh | grad: 0.0
# label:  | data: -0.9999292462884456 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998506936166 | operation: tanh | grad: 0.0
# epoch_loss: 232.9999676999436
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch: 99
# predictions:
# label:  | data: 0.9999998338156425 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998529771912 | operation: tanh | grad: 0.0
# label:  | data: -0.9999291583674639 | operation: tanh | grad: 0.0
# label:  | data: 0.9999998506485906 | operation: tanh | grad: 0.0
# epoch_loss: 232.99996765691296
# ------------------------------------------------------------------------------------------------------------------------------------------------------
